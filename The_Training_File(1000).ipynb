# %% [markdown]
# # A Quantum-Enhanced LSTM Layer

# %% [markdown]
# Kuantum Makine Öğrenmesinde şimdiye kadar yeterince araştırılmamış bir alan, bilgisayarlara yazılı metni okuma, yazma ve bir dereceye kadar anlama yeteneği veren Yapay Zekâ'nın alt alanı olan Doğal Dil İşleme'dir (NLP).
#
# Belgeler genellikle kelime dizileri olarak sunulduğundan, tarihsel olarak bu tür verileri işlemek için en başarılı tekniklerden biri Tekrarlayan Sinir Ağı mimarisi ve özellikle Uzun Kısa Süreli Bellek (LSTM) adı verilen bir varyant olmuştur. LSTM'ler, makinelerin Transformatör ağlarının ortaya çıkışına kadar en son teknoloji doğrulukla çeviriler, sınıflandırmalar ve niyet tespiti yapmalarına olanak sağladı. Yine de, iyi kuantum hesaplamanın alana ne getirebileceğini görmek için LSTM'leri araştırmak en azından eğitim açısından ilginçtir. Daha ayrıntılı bir tartışma için lütfen Chen, Yoo ve Fang'ın "Kuantum Uzun Kısa Süreli Bellek" (arXiv:2009.01783) ve J. Bausch'un "Tekrarlayan Kuantum Sinir Ağları" (arXiv:2006.14619) makalelerine bakın.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from quantum_lstm import QLSTM #./quantum_lstm.py

# %%
import pandas as pd
df=pd.read_csv('turkish_ud_741.5K.csv')
# Universal Dependencies Veri Seti Türkçe

# %%
df.head()
# Out:
#                                             Sentence  \
# 0                      1936 yılındayız yılında yız .
# 1    Adeta kendimden geçmiş bir haldeyim halde yim .
# 2  O nasıl derse desin uğraştığı sanatın kendisin...
# 3  Ahmed Rasim , Büyükada'ya gidip birkaç gün kal...
# 4             Rüzgâr yine güçlü esiyordu esiyor du .
#
#                                        UPOS Sequence
# 0                               NUM _ NOUN AUX PUNCT
# 1                 ADV PRON VERB DET _ NOUN AUX PUNCT
# 2  PRON ADV VERB VERB VERB NOUN PRON NOUN VERB VE...
# 3  PROPN PROPN PUNCT PROPN VERB DET NOUN VERB _ V...
# 4                      NOUN ADV ADV _ VERB AUX PUNCT

# %%
sequences = df['UPOS Sequence'].str.split(expand=True).stack().unique()

print(sequences)
# Out:
# ['NUM' '_' 'NOUN' 'AUX' 'PUNCT' 'ADV' 'PRON' 'VERB' 'DET' 'PROPN' 'ADJ'
#  'CCONJ' 'ADP' 'PART' 'SCONJ' 'INTJ' 'X' 'SYM']

# %%
tag_to_ix = {'_': 0, 'ADJ': 1, 'ADP': 2, 'ADV': 3, 'AUX': 4, 'CCONJ': 5, 'DET': 6, 'INTJ': 7, 'NOUN': 8, 'NUM': 9, 'PART': 10, 'PRON': 11, 'PROPN': 12, 'PUNCT': 13, 'SCONJ': 14, 'VERB': 15, 'X': 16, 'SYM':17} # Assign each tag with a unique index
ix_to_tag = {i:k for k,i in tag_to_ix.items()}

# %% [markdown]
# Aşağıdaki fonksiyon cümleyi kelimelere ayırır ve etiketi her kelimeyle eşleştirir.

# %%
def prepare_sequence(seq, to_ix):
    idxs = [to_ix[w] for w in seq]
    return torch.tensor(idxs, dtype=torch.long)

# %% [markdown]
# Aşağıdaki döngü eğitim veri setini oluşturur.

# %%
training_data = []
word_to_ix = {}
tag_to_ix = {}

for _, row in df.iterrows():
    words = row['Sentence'].split()
    tags = row['UPOS Sequence'].split()
    training_data.append((words, tags))
    for word in words:
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)
    for tag in tags:
        if tag not in tag_to_ix:
            tag_to_ix[tag] = len(tag_to_ix)

print(f"Training Data: {training_data}")
print(f"Word to Index: {word_to_ix}")
print(f"Tag to Index: {tag_to_ix}")
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Fikir, her kelime için bir tane olmak üzere gizli vektör dizisini [h_0, h_1, h_2, h_3, h_4] çıktısı verecek olan iki diziyi LSTM'den geçirmektir. Her kelimenin bir belirleyici, isim veya fiil olma olasılığını hesaplamak için LSTM'nin çıktılarına yoğun bir katman "head" eklenir.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class LSTMTagger(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size, pretrained_embeddings=None,
                 n_qubits=0, num_layers=4, n_qlayers=4, freeze_embeddings=False):
        super(LSTMTagger, self).__init__()
        self.hidden_dim = hidden_dim


        if pretrained_embeddings is not None:

            self.word_embeddings = nn.Embedding.from_pretrained(pretrained_embeddings, freeze=freeze_embeddings)
        else:
    
            self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)


        if n_qubits > 0:
            print("Tagger will use Quantum LSTM")
            self.lstm = QLSTM(embedding_dim, hidden_dim, n_qubits=n_qubits, n_qlayers=n_qlayers)
        else:
            print("Tagger will use Classical LSTM")
            self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=num_layers, batch_first=True)

        self.hidden2tag = nn.Linear(hidden_dim, tagset_size)

    def forward(self, sentence):
        embeds = self.word_embeddings(sentence)
        lstm_out, _ = self.lstm(embeds.view(len(sentence), 1, -1))
        tag_logits = self.hidden2tag(lstm_out.view(len(sentence), -1))
        tag_scores = F.log_softmax(tag_logits, dim=1)
        return tag_scores

# %%
embedding_dim = 8
hidden_dim = 6
n_epochs = 300

# %%
model_classical = LSTMTagger(embedding_dim,
                        hidden_dim,
                        vocab_size=len(word_to_ix),
                        tagset_size=len(tag_to_ix),
                        n_qubits=0)
# Out:
# Tagger will use Classical LSTM

# %% [markdown]
# ## Training

# %% [markdown]
# Following the example from the PyTorch website, we train the two networks (classical and quantum LSTM) for 300 epochs.

# %%
def train(model, n_epochs):
    loss_function = nn.NLLLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.1)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.8)

    history = {
        'loss': [],
        'acc': []
    }
    for epoch in range(n_epochs):
        losses = []
        preds = []
        targets = []
        for sentence, tags in training_data:
            model.zero_grad()
            sentence_in = prepare_sequence(sentence, word_to_ix)
            labels = prepare_sequence(tags, tag_to_ix)

            tag_scores = model(sentence_in)
            loss = loss_function(tag_scores, labels)
            loss.backward()
            optimizer.step()
            losses.append(float(loss))

            probs = torch.softmax(tag_scores, dim=-1)
            preds.append(probs.argmax(dim=-1))
            targets.append(labels)

        avg_loss = np.mean(losses)
        history['loss'].append(avg_loss)

        preds = torch.cat(preds)
        targets = torch.cat(targets)
        corrects = (preds == targets)
        accuracy = corrects.sum().float() / float(targets.size(0))
        history['acc'].append(accuracy)


        scheduler.step()

        print(f"Epoch {epoch+1} / {n_epochs}: Loss = {avg_loss:.3f}, Acc = {accuracy:.2f}, LR = {scheduler.get_last_lr()[0]:.6f}")

    return history

# %%
history_classical = train(model_classical, n_epochs)
# Out:
# Epoch 1 / 300: Loss = 1.560, Acc = 0.48, LR = 0.100000
# Epoch 2 / 300: Loss = 1.284, Acc = 0.56, LR = 0.100000
# Epoch 3 / 300: Loss = 1.113, Acc = 0.61, LR = 0.100000
# Epoch 4 / 300: Loss = 1.013, Acc = 0.64, LR = 0.100000
# Epoch 5 / 300: Loss = 0.984, Acc = 0.65, LR = 0.100000
# Epoch 6 / 300: Loss = 0.905, Acc = 0.67, LR = 0.100000
# Epoch 7 / 300: Loss = 0.879, Acc = 0.68, LR = 0.080000
# Epoch 8 / 300: Loss = 0.860, Acc = 0.69, LR = 0.080000
# Epoch 9 / 300: Loss = 0.876, Acc = 0.69, LR = 0.080000
# Epoch 10 / 300: Loss = 0.848, Acc = 0.70, LR = 0.080000
# Epoch 11 / 300: Loss = 0.841, Acc = 0.71, LR = 0.080000
# Epoch 12 / 300: Loss = 0.854, Acc = 0.71, LR = 0.080000
# Epoch 13 / 300: Loss = 0.849, Acc = 0.71, LR = 0.080000
# Epoch 14 / 300: Loss = 0.954, Acc = 0.68, LR = 0.064000
# Epoch 15 / 300: Loss = 0.997, Acc = 0.66, LR = 0.064000
# Epoch 16 / 300: Loss = 0.830, Acc = 0.72, LR = 0.064000
# Epoch 17 / 300: Loss = 0.791, Acc = 0.74, LR = 0.064000
# Epoch 18 / 300: Loss = 0.794, Acc = 0.73, LR = 0.064000
# Epoch 19 / 300: Loss = 1.004, Acc = 0.65, LR = 0.064000
# Epoch 20 / 300: Loss = 1.049, Acc = 0.64, LR = 0.064000
# Epoch 21 / 300: Loss = 0.895, Acc = 0.69, LR = 0.051200
# Epoch 22 / 300: Loss = 0.762, Acc = 0.74, LR = 0.051200
# Epoch 23 / 300: Loss = 0.732, Acc = 0.75, LR = 0.051200
# Epoch 24 / 300: Loss = 0.710, Acc = 0.76, LR = 0.051200
# Epoch 25 / 300: Loss = 0.694, Acc = 0.77, LR = 0.051200
# Epoch 26 / 300: Loss = 0.770, Acc = 0.74, LR = 0.051200
# Epoch 27 / 300: Loss = 1.018, Acc = 0.65, LR = 0.051200
# Epoch 28 / 300: Loss = 0.842, Acc = 0.73, LR = 0.040960
# Epoch 29 / 300: Loss = 0.771, Acc = 0.76, LR = 0.040960
# Epoch 30 / 300: Loss = 0.985, Acc = 0.66, LR = 0.040960
# Epoch 31 / 300: Loss = 0.772, Acc = 0.75, LR = 0.040960
# Epoch 32 / 300: Loss = 0.744, Acc = 0.76, LR = 0.040960
# Epoch 33 / 300: Loss = 0.741, Acc = 0.76, LR = 0.040960
# Epoch 34 / 300: Loss = 0.730, Acc = 0.77, LR = 0.040960
# Epoch 35 / 300: Loss = 0.969, Acc = 0.68, LR = 0.032768
# Epoch 36 / 300: Loss = 0.734, Acc = 0.77, LR = 0.032768
# Epoch 37 / 300: Loss = 0.689, Acc = 0.78, LR = 0.032768
# Epoch 38 / 300: Loss = 0.673, Acc = 0.78, LR = 0.032768
# Epoch 39 / 300: Loss = 0.669, Acc = 0.79, LR = 0.032768
# Epoch 40 / 300: Loss = 0.648, Acc = 0.79, LR = 0.032768
# Epoch 41 / 300: Loss = 0.704, Acc = 0.77, LR = 0.032768
# Epoch 42 / 300: Loss = 0.812, Acc = 0.73, LR = 0.026214
# Epoch 43 / 300: Loss = 0.762, Acc = 0.75, LR = 0.026214
# Epoch 44 / 300: Loss = 0.714, Acc = 0.77, LR = 0.026214
# Epoch 45 / 300: Loss = 0.777, Acc = 0.75, LR = 0.026214
# Epoch 46 / 300: Loss = 0.808, Acc = 0.74, LR = 0.026214
# Epoch 47 / 300: Loss = 0.799, Acc = 0.73, LR = 0.026214
# Epoch 48 / 300: Loss = 0.725, Acc = 0.76, LR = 0.026214
# Epoch 49 / 300: Loss = 0.888, Acc = 0.69, LR = 0.020972
# Epoch 50 / 300: Loss = 0.707, Acc = 0.77, LR = 0.020972
# Epoch 51 / 300: Loss = 0.645, Acc = 0.79, LR = 0.020972
# Epoch 52 / 300: Loss = 0.648, Acc = 0.79, LR = 0.020972
# Epoch 53 / 300: Loss = 0.695, Acc = 0.78, LR = 0.020972
# Epoch 54 / 300: Loss = 0.746, Acc = 0.76, LR = 0.020972
# Epoch 55 / 300: Loss = 0.694, Acc = 0.77, LR = 0.020972
# Epoch 56 / 300: Loss = 0.719, Acc = 0.76, LR = 0.016777
# Epoch 57 / 300: Loss = 0.620, Acc = 0.80, LR = 0.016777
# Epoch 58 / 300: Loss = 0.626, Acc = 0.80, LR = 0.016777
# Epoch 59 / 300: Loss = 0.637, Acc = 0.79, LR = 0.016777
# Epoch 60 / 300: Loss = 0.671, Acc = 0.78, LR = 0.016777
# Epoch 61 / 300: Loss = 0.677, Acc = 0.78, LR = 0.016777
# Epoch 62 / 300: Loss = 0.754, Acc = 0.75, LR = 0.016777
# Epoch 63 / 300: Loss = 0.722, Acc = 0.77, LR = 0.013422
# Epoch 64 / 300: Loss = 0.637, Acc = 0.80, LR = 0.013422
# Epoch 65 / 300: Loss = 0.615, Acc = 0.80, LR = 0.013422
# Epoch 66 / 300: Loss = 0.671, Acc = 0.78, LR = 0.013422
# Epoch 67 / 300: Loss = 0.769, Acc = 0.74, LR = 0.013422
# Epoch 68 / 300: Loss = 0.684, Acc = 0.78, LR = 0.013422
# Epoch 69 / 300: Loss = 0.666, Acc = 0.79, LR = 0.013422
# Epoch 70 / 300: Loss = 0.688, Acc = 0.78, LR = 0.010737
# Epoch 71 / 300: Loss = 0.718, Acc = 0.77, LR = 0.010737
# Epoch 72 / 300: Loss = 0.686, Acc = 0.78, LR = 0.010737
# Epoch 73 / 300: Loss = 0.978, Acc = 0.68, LR = 0.010737
# Epoch 74 / 300: Loss = 0.711, Acc = 0.77, LR = 0.010737
# Epoch 75 / 300: Loss = 0.650, Acc = 0.80, LR = 0.010737
# Epoch 76 / 300: Loss = 0.707, Acc = 0.78, LR = 0.010737
# Epoch 77 / 300: Loss = 0.943, Acc = 0.68, LR = 0.008590
# Epoch 78 / 300: Loss = 0.799, Acc = 0.73, LR = 0.008590
# Epoch 79 / 300: Loss = 0.763, Acc = 0.74, LR = 0.008590
# Epoch 80 / 300: Loss = 0.745, Acc = 0.75, LR = 0.008590
# Epoch 81 / 300: Loss = 0.730, Acc = 0.75, LR = 0.008590
# Epoch 82 / 300: Loss = 0.716, Acc = 0.76, LR = 0.008590
# Epoch 83 / 300: Loss = 0.704, Acc = 0.76, LR = 0.008590
# Epoch 84 / 300: Loss = 0.687, Acc = 0.77, LR = 0.006872
# Epoch 85 / 300: Loss = 0.675, Acc = 0.77, LR = 0.006872
# Epoch 86 / 300: Loss = 0.665, Acc = 0.78, LR = 0.006872
# Epoch 87 / 300: Loss = 0.659, Acc = 0.78, LR = 0.006872
# Epoch 88 / 300: Loss = 0.653, Acc = 0.78, LR = 0.006872
# Epoch 89 / 300: Loss = 0.646, Acc = 0.78, LR = 0.006872
# Epoch 90 / 300: Loss = 0.641, Acc = 0.79, LR = 0.006872
# Epoch 91 / 300: Loss = 0.637, Acc = 0.79, LR = 0.005498
# Epoch 92 / 300: Loss = 0.633, Acc = 0.79, LR = 0.005498
# Epoch 93 / 300: Loss = 0.629, Acc = 0.79, LR = 0.005498
# Epoch 94 / 300: Loss = 0.620, Acc = 0.79, LR = 0.005498
# Epoch 95 / 300: Loss = 0.615, Acc = 0.80, LR = 0.005498
# Epoch 96 / 300: Loss = 0.611, Acc = 0.80, LR = 0.005498
# Epoch 97 / 300: Loss = 0.609, Acc = 0.80, LR = 0.005498
# Epoch 98 / 300: Loss = 0.606, Acc = 0.80, LR = 0.004398
# Epoch 99 / 300: Loss = 0.604, Acc = 0.80, LR = 0.004398
# Epoch 100 / 300: Loss = 0.602, Acc = 0.80, LR = 0.004398
# Epoch 101 / 300: Loss = 0.599, Acc = 0.80, LR = 0.004398
# Epoch 102 / 300: Loss = 0.597, Acc = 0.80, LR = 0.004398
# Epoch 103 / 300: Loss = 0.595, Acc = 0.81, LR = 0.004398
# Epoch 104 / 300: Loss = 0.593, Acc = 0.81, LR = 0.004398
# Epoch 105 / 300: Loss = 0.591, Acc = 0.81, LR = 0.003518
# Epoch 106 / 300: Loss = 0.590, Acc = 0.81, LR = 0.003518
# Epoch 107 / 300: Loss = 0.588, Acc = 0.81, LR = 0.003518
# Epoch 108 / 300: Loss = 0.587, Acc = 0.81, LR = 0.003518
# Epoch 109 / 300: Loss = 0.585, Acc = 0.81, LR = 0.003518
# Epoch 110 / 300: Loss = 0.584, Acc = 0.81, LR = 0.003518
# Epoch 111 / 300: Loss = 0.583, Acc = 0.81, LR = 0.003518
# Epoch 112 / 300: Loss = 0.581, Acc = 0.81, LR = 0.002815
# Epoch 113 / 300: Loss = 0.581, Acc = 0.81, LR = 0.002815
# Epoch 114 / 300: Loss = 0.580, Acc = 0.81, LR = 0.002815
# Epoch 115 / 300: Loss = 0.578, Acc = 0.81, LR = 0.002815
# Epoch 116 / 300: Loss = 0.577, Acc = 0.81, LR = 0.002815
# Epoch 117 / 300: Loss = 0.576, Acc = 0.81, LR = 0.002815
# Epoch 118 / 300: Loss = 0.574, Acc = 0.81, LR = 0.002815
# Epoch 119 / 300: Loss = 0.573, Acc = 0.82, LR = 0.002252
# Epoch 120 / 300: Loss = 0.574, Acc = 0.82, LR = 0.002252
# Epoch 121 / 300: Loss = 0.573, Acc = 0.82, LR = 0.002252
# Epoch 122 / 300: Loss = 0.574, Acc = 0.82, LR = 0.002252
# Epoch 123 / 300: Loss = 0.572, Acc = 0.82, LR = 0.002252
# Epoch 124 / 300: Loss = 0.570, Acc = 0.82, LR = 0.002252
# Epoch 125 / 300: Loss = 0.569, Acc = 0.82, LR = 0.002252
# Epoch 126 / 300: Loss = 0.568, Acc = 0.82, LR = 0.001801
# Epoch 127 / 300: Loss = 0.570, Acc = 0.82, LR = 0.001801
# Epoch 128 / 300: Loss = 0.569, Acc = 0.82, LR = 0.001801
# Epoch 129 / 300: Loss = 0.568, Acc = 0.82, LR = 0.001801
# Epoch 130 / 300: Loss = 0.569, Acc = 0.82, LR = 0.001801
# Epoch 131 / 300: Loss = 0.570, Acc = 0.82, LR = 0.001801
# Epoch 132 / 300: Loss = 0.567, Acc = 0.82, LR = 0.001801
# Epoch 133 / 300: Loss = 0.566, Acc = 0.82, LR = 0.001441
# Epoch 134 / 300: Loss = 0.566, Acc = 0.82, LR = 0.001441
# Epoch 135 / 300: Loss = 0.565, Acc = 0.82, LR = 0.001441
# Epoch 136 / 300: Loss = 0.564, Acc = 0.82, LR = 0.001441
# Epoch 137 / 300: Loss = 0.563, Acc = 0.82, LR = 0.001441
# Epoch 138 / 300: Loss = 0.563, Acc = 0.82, LR = 0.001441
# Epoch 139 / 300: Loss = 0.562, Acc = 0.82, LR = 0.001441
# Epoch 140 / 300: Loss = 0.561, Acc = 0.83, LR = 0.001153
# Epoch 141 / 300: Loss = 0.562, Acc = 0.83, LR = 0.001153
# Epoch 142 / 300: Loss = 0.562, Acc = 0.83, LR = 0.001153
# Epoch 143 / 300: Loss = 0.561, Acc = 0.83, LR = 0.001153
# Epoch 144 / 300: Loss = 0.561, Acc = 0.83, LR = 0.001153
# Epoch 145 / 300: Loss = 0.561, Acc = 0.83, LR = 0.001153
# Epoch 146 / 300: Loss = 0.560, Acc = 0.83, LR = 0.001153
# Epoch 147 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000922
# Epoch 148 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000922
# Epoch 149 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000922
# Epoch 150 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000922
# Epoch 151 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000922
# Epoch 152 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000922
# Epoch 153 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000922
# Epoch 154 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000738
# Epoch 155 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000738
# Epoch 156 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000738
# Epoch 157 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000738
# Epoch 158 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000738
# Epoch 159 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000738
# Epoch 160 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000738
# Epoch 161 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000590
# Epoch 162 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000590
# Epoch 163 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000590
# Epoch 164 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000590
# Epoch 165 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000590
# Epoch 166 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000590
# Epoch 167 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000590
# Epoch 168 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000472
# Epoch 169 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000472
# Epoch 170 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000472
# Epoch 171 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000472
# Epoch 172 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000472
# Epoch 173 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000472
# Epoch 174 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000472
# Epoch 175 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000378
# Epoch 176 / 300: Loss = 0.562, Acc = 0.83, LR = 0.000378
# Epoch 177 / 300: Loss = 0.562, Acc = 0.83, LR = 0.000378
# Epoch 178 / 300: Loss = 0.562, Acc = 0.83, LR = 0.000378
# Epoch 179 / 300: Loss = 0.562, Acc = 0.83, LR = 0.000378
# Epoch 180 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000378
# Epoch 181 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000378
# Epoch 182 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000302
# Epoch 183 / 300: Loss = 0.563, Acc = 0.83, LR = 0.000302
# Epoch 184 / 300: Loss = 0.563, Acc = 0.83, LR = 0.000302
# Epoch 185 / 300: Loss = 0.563, Acc = 0.83, LR = 0.000302
# Epoch 186 / 300: Loss = 0.563, Acc = 0.83, LR = 0.000302
# Epoch 187 / 300: Loss = 0.562, Acc = 0.83, LR = 0.000302
# Epoch 188 / 300: Loss = 0.562, Acc = 0.83, LR = 0.000302
# Epoch 189 / 300: Loss = 0.562, Acc = 0.83, LR = 0.000242
# Epoch 190 / 300: Loss = 0.564, Acc = 0.83, LR = 0.000242
# Epoch 191 / 300: Loss = 0.564, Acc = 0.83, LR = 0.000242
# Epoch 192 / 300: Loss = 0.564, Acc = 0.83, LR = 0.000242
# Epoch 193 / 300: Loss = 0.564, Acc = 0.83, LR = 0.000242
# Epoch 194 / 300: Loss = 0.564, Acc = 0.83, LR = 0.000242
# Epoch 195 / 300: Loss = 0.564, Acc = 0.83, LR = 0.000242
# Epoch 196 / 300: Loss = 0.563, Acc = 0.83, LR = 0.000193
# Epoch 197 / 300: Loss = 0.566, Acc = 0.83, LR = 0.000193
# Epoch 198 / 300: Loss = 0.565, Acc = 0.83, LR = 0.000193
# Epoch 199 / 300: Loss = 0.565, Acc = 0.83, LR = 0.000193
# Epoch 200 / 300: Loss = 0.565, Acc = 0.83, LR = 0.000193
# Epoch 201 / 300: Loss = 0.565, Acc = 0.83, LR = 0.000193
# Epoch 202 / 300: Loss = 0.565, Acc = 0.83, LR = 0.000193
# Epoch 203 / 300: Loss = 0.565, Acc = 0.83, LR = 0.000155
# Epoch 204 / 300: Loss = 0.567, Acc = 0.83, LR = 0.000155
# Epoch 205 / 300: Loss = 0.567, Acc = 0.83, LR = 0.000155
# Epoch 206 / 300: Loss = 0.567, Acc = 0.83, LR = 0.000155
# Epoch 207 / 300: Loss = 0.567, Acc = 0.83, LR = 0.000155
# Epoch 208 / 300: Loss = 0.567, Acc = 0.83, LR = 0.000155
# Epoch 209 / 300: Loss = 0.566, Acc = 0.83, LR = 0.000155
# Epoch 210 / 300: Loss = 0.566, Acc = 0.83, LR = 0.000124
# Epoch 211 / 300: Loss = 0.569, Acc = 0.83, LR = 0.000124
# Epoch 212 / 300: Loss = 0.568, Acc = 0.83, LR = 0.000124
# Epoch 213 / 300: Loss = 0.568, Acc = 0.83, LR = 0.000124
# Epoch 214 / 300: Loss = 0.568, Acc = 0.83, LR = 0.000124
# Epoch 215 / 300: Loss = 0.568, Acc = 0.83, LR = 0.000124
# Epoch 216 / 300: Loss = 0.568, Acc = 0.83, LR = 0.000124
# Epoch 217 / 300: Loss = 0.568, Acc = 0.83, LR = 0.000099
# Epoch 218 / 300: Loss = 0.571, Acc = 0.83, LR = 0.000099
# Epoch 219 / 300: Loss = 0.570, Acc = 0.83, LR = 0.000099
# Epoch 220 / 300: Loss = 0.570, Acc = 0.83, LR = 0.000099
# Epoch 221 / 300: Loss = 0.570, Acc = 0.83, LR = 0.000099
# Epoch 222 / 300: Loss = 0.570, Acc = 0.83, LR = 0.000099
# Epoch 223 / 300: Loss = 0.570, Acc = 0.83, LR = 0.000099
# Epoch 224 / 300: Loss = 0.570, Acc = 0.83, LR = 0.000079
# Epoch 225 / 300: Loss = 0.573, Acc = 0.83, LR = 0.000079
# Epoch 226 / 300: Loss = 0.572, Acc = 0.83, LR = 0.000079
# Epoch 227 / 300: Loss = 0.572, Acc = 0.83, LR = 0.000079
# Epoch 228 / 300: Loss = 0.572, Acc = 0.83, LR = 0.000079
# Epoch 229 / 300: Loss = 0.572, Acc = 0.83, LR = 0.000079
# Epoch 230 / 300: Loss = 0.572, Acc = 0.83, LR = 0.000079
# Epoch 231 / 300: Loss = 0.572, Acc = 0.83, LR = 0.000063
# Epoch 232 / 300: Loss = 0.575, Acc = 0.83, LR = 0.000063
# Epoch 233 / 300: Loss = 0.575, Acc = 0.83, LR = 0.000063
# Epoch 234 / 300: Loss = 0.575, Acc = 0.83, LR = 0.000063
# Epoch 235 / 300: Loss = 0.575, Acc = 0.83, LR = 0.000063
# Epoch 236 / 300: Loss = 0.575, Acc = 0.83, LR = 0.000063
# Epoch 237 / 300: Loss = 0.575, Acc = 0.83, LR = 0.000063
# Epoch 238 / 300: Loss = 0.575, Acc = 0.83, LR = 0.000051
# Epoch 239 / 300: Loss = 0.577, Acc = 0.83, LR = 0.000051
# Epoch 240 / 300: Loss = 0.577, Acc = 0.83, LR = 0.000051
# Epoch 241 / 300: Loss = 0.577, Acc = 0.83, LR = 0.000051
# Epoch 242 / 300: Loss = 0.577, Acc = 0.83, LR = 0.000051
# Epoch 243 / 300: Loss = 0.577, Acc = 0.83, LR = 0.000051
# Epoch 244 / 300: Loss = 0.577, Acc = 0.83, LR = 0.000051
# Epoch 245 / 300: Loss = 0.577, Acc = 0.83, LR = 0.000041
# Epoch 246 / 300: Loss = 0.580, Acc = 0.82, LR = 0.000041
# Epoch 247 / 300: Loss = 0.580, Acc = 0.82, LR = 0.000041
# Epoch 248 / 300: Loss = 0.580, Acc = 0.82, LR = 0.000041
# Epoch 249 / 300: Loss = 0.580, Acc = 0.82, LR = 0.000041
# Epoch 250 / 300: Loss = 0.580, Acc = 0.82, LR = 0.000041
# Epoch 251 / 300: Loss = 0.580, Acc = 0.82, LR = 0.000041
# Epoch 252 / 300: Loss = 0.580, Acc = 0.82, LR = 0.000032
# Epoch 253 / 300: Loss = 0.583, Acc = 0.82, LR = 0.000032
# Epoch 254 / 300: Loss = 0.583, Acc = 0.82, LR = 0.000032
# Epoch 255 / 300: Loss = 0.583, Acc = 0.82, LR = 0.000032
# Epoch 256 / 300: Loss = 0.583, Acc = 0.82, LR = 0.000032
# Epoch 257 / 300: Loss = 0.583, Acc = 0.82, LR = 0.000032
# Epoch 258 / 300: Loss = 0.583, Acc = 0.82, LR = 0.000032
# Epoch 259 / 300: Loss = 0.583, Acc = 0.82, LR = 0.000026
# Epoch 260 / 300: Loss = 0.586, Acc = 0.82, LR = 0.000026
# Epoch 261 / 300: Loss = 0.586, Acc = 0.82, LR = 0.000026
# Epoch 262 / 300: Loss = 0.585, Acc = 0.82, LR = 0.000026
# Epoch 263 / 300: Loss = 0.585, Acc = 0.82, LR = 0.000026
# Epoch 264 / 300: Loss = 0.585, Acc = 0.82, LR = 0.000026
# Epoch 265 / 300: Loss = 0.585, Acc = 0.82, LR = 0.000026
# Epoch 266 / 300: Loss = 0.585, Acc = 0.82, LR = 0.000021
# Epoch 267 / 300: Loss = 0.588, Acc = 0.82, LR = 0.000021
# Epoch 268 / 300: Loss = 0.588, Acc = 0.82, LR = 0.000021
# Epoch 269 / 300: Loss = 0.588, Acc = 0.82, LR = 0.000021
# Epoch 270 / 300: Loss = 0.588, Acc = 0.82, LR = 0.000021
# Epoch 271 / 300: Loss = 0.588, Acc = 0.82, LR = 0.000021
# Epoch 272 / 300: Loss = 0.588, Acc = 0.82, LR = 0.000021
# Epoch 273 / 300: Loss = 0.588, Acc = 0.82, LR = 0.000017
# Epoch 274 / 300: Loss = 0.591, Acc = 0.82, LR = 0.000017
# Epoch 275 / 300: Loss = 0.591, Acc = 0.82, LR = 0.000017
# Epoch 276 / 300: Loss = 0.591, Acc = 0.82, LR = 0.000017
# Epoch 277 / 300: Loss = 0.591, Acc = 0.82, LR = 0.000017
# Epoch 278 / 300: Loss = 0.591, Acc = 0.82, LR = 0.000017
# Epoch 279 / 300: Loss = 0.591, Acc = 0.82, LR = 0.000017
# Epoch 280 / 300: Loss = 0.591, Acc = 0.82, LR = 0.000013
# Epoch 281 / 300: Loss = 0.593, Acc = 0.82, LR = 0.000013
# Epoch 282 / 300: Loss = 0.593, Acc = 0.82, LR = 0.000013
# Epoch 283 / 300: Loss = 0.593, Acc = 0.82, LR = 0.000013
# Epoch 284 / 300: Loss = 0.593, Acc = 0.82, LR = 0.000013
# Epoch 285 / 300: Loss = 0.593, Acc = 0.82, LR = 0.000013
# Epoch 286 / 300: Loss = 0.593, Acc = 0.82, LR = 0.000013
# Epoch 287 / 300: Loss = 0.593, Acc = 0.82, LR = 0.000011
# Epoch 288 / 300: Loss = 0.596, Acc = 0.82, LR = 0.000011
# Epoch 289 / 300: Loss = 0.596, Acc = 0.82, LR = 0.000011
# Epoch 290 / 300: Loss = 0.596, Acc = 0.82, LR = 0.000011
# Epoch 291 / 300: Loss = 0.596, Acc = 0.82, LR = 0.000011
# Epoch 292 / 300: Loss = 0.596, Acc = 0.82, LR = 0.000011
# Epoch 293 / 300: Loss = 0.596, Acc = 0.82, LR = 0.000011
# Epoch 294 / 300: Loss = 0.596, Acc = 0.82, LR = 0.000009
# Epoch 295 / 300: Loss = 0.598, Acc = 0.82, LR = 0.000009
# Epoch 296 / 300: Loss = 0.598, Acc = 0.82, LR = 0.000009
# Epoch 297 / 300: Loss = 0.598, Acc = 0.82, LR = 0.000009
# Epoch 298 / 300: Loss = 0.598, Acc = 0.82, LR = 0.000009
# Epoch 299 / 300: Loss = 0.598, Acc = 0.82, LR = 0.000009
# Epoch 300 / 300: Loss = 0.598, Acc = 0.82, LR = 0.000009

# %%
torch.save(model_classical.state_dict(), "lstm_tagger_turkish.pth")

# %%
def print_result(model):
    with torch.no_grad():
        input_sentence = training_data[0][0]
        labels = training_data[0][1]
        inputs = prepare_sequence(input_sentence, word_to_ix)
        tag_scores = model(inputs)

        tag_ids = torch.argmax(tag_scores, dim=1).numpy()
        tag_labels = [ix_to_tag[k] for k in tag_ids]
        print(f"Sentence:  {input_sentence}")
        print(f"Labels:    {labels}")
        print(f"Predicted: {tag_labels}")

# %%
print_result(model_classical)
# Out:
# Sentence:  ['1936', 'yılındayız', 'yılında', 'yız', '.']
# Labels:    ['NUM', '_', 'NOUN', 'AUX', 'PUNCT']
# Predicted: ['SYM', 'SYM', 'SYM', 'SYM', 'SYM']

# %%
df=df.sample(1000)

# %%
training_data = []
word_to_ix = {}
tag_to_ix = {}

for _, row in df.iterrows():
    words = row['Sentence'].split()
    tags = row['UPOS Sequence'].split()
    training_data.append((words, tags))
    for word in words:
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)
    for tag in tags:
        if tag not in tag_to_ix:
            tag_to_ix[tag] = len(tag_to_ix)

print(f"Training Data: {training_data}")
print(f"Word to Index: {word_to_ix}")
print(f"Tag to Index: {tag_to_ix}")
# Out:
# Training Data: [(['YİYECEK', 'İÇECEKLERDEN', '.'], ['NOUN', 'NOUN', 'PUNCT']), (['Başlıca', 'fosforışıl', 'cisimler', 'kalsiyum', 'sülfür', ',', 'radyum', 'sülfür', ',', 'stronsiyum', 'sülfür', 've', 'çinko', 'sülfürdür', '.'], ['ADJ', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'PUNCT', 'NOUN', 'NOUN', 'PUNCT', 'NOUN', 'NOUN', 'CCONJ', 'NOUN', 'VERB', 'PUNCT']), (['İNCİ', 'HANIMDI', '.'], ['PROPN', 'VERB', 'PUNCT']), (['Bu', 'müthiş', 'yokluğa', ',', 'bu', 'derin', 'acıya', 'tahammül', 'edemiyordum', '.'], ['DET', 'ADJ', 'NOUN', 'PUNCT', 'DET', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'PUNCT']), (['Şirket', 'alımı', "BSN'nin", 'Avrupa', 'makarna', 'piyasasındaki', 'konumunu', 'güçlendiriyor', '.'], ['NOUN', 'NOUN', 'PROPN', 'PROPN', 'NOUN', 'ADJ', 'NOUN', 'VERB', 'PUNCT']), (['2', "Ağustos'ta", "Washington'dan", 'uçuşlar'], ['NUM', 'PROPN', 'PROPN', 'NOUN']), (['Bana', 'San', "Jose'den", "Phoenix'e", 'olan', 'tüm', 'uçuşları', 'gösterin'], ['PRON', 'PROPN', 'PROPN', 'PROPN', 'ADJ', 'DET', 'NOUN', 'VERB']), (['17', 'Haziran’da'], ['NUM', 'NOUN']), (['Oyunun', 'önemli', 'sahnelerinde', ',', 'Bay', 'Boyd', "Shakespeare'nin", 'dinamiğini', 'yakalayan', 'bir', 'firması', 'olduğunu', 'gösteriyor', '.'], ['NOUN', 'ADJ', 'NOUN', 'PUNCT', 'NOUN', 'PROPN', 'PROPN', 'NOUN', 'ADJ', 'DET', 'NOUN', 'NOUN', 'VERB', 'PUNCT']), (['Toz', 'kondurmadığı', 'devletinin', 'kendisini', 'hatırlamasını', 'sabırla', 'bekliyor', '.'], ['NOUN', 'NOUN', 'NOUN', 'PRON', 'NOUN', 'NOUN', 'VERB', 'PUNCT']), (['Serseri', 'güruhunun', 'başlarından', 'düşmeyen', 'siperli', 'sipersiz', 'kapelalarla', '.'], ['ADJ', 'NOUN', 'NOUN', 'ADJ', 'ADJ', 'ADJ', 'NOUN', 'PUNCT']), (['TAM', 'PUAN', 'VERİYORUM', '6', 'PUAN', '.'], ['ADV', 'NOUN', 'VERB', 'NUM', 'NOUN', 'PUNCT']), (['Benimki', 'vehim', ',', 'bedbinlik', ',', 'şiddetli', 'arzularda', 'duyulan', 'kaybetme', 'korkusu', '.'], ['ADJ', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'ADJ', 'NOUN', 'ADJ', 'NOUN', 'NOUN', 'PUNCT']), (['Gazi', 'daha', 'çok', 'kuru', 'leblebiyi', 'tercih', 'ederdi', '.'], ['PROPN', 'ADV', 'ADV', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'PUNCT']), (["Nazmiye'nin", 'tepesinden', 'sanki', 'kaynar', 'sular', 'döküldü', ',', 'yo', 'dedi', '.'], ['PROPN', 'NOUN', 'ADV', 'ADJ', 'NOUN', 'VERB', 'PUNCT', 'INTJ', 'VERB', 'PUNCT']), (['Malzemeler', ':'], ['NOUN', 'PUNCT']), (['Yanıtlar', 'ABD', 'Nüfus', 'Sayımı', 'verilerine', 'uyacak', 'şekilde', 'yaş', 've', 'cinsiyete', 'göre', 'ağırlıklandırılmıştır', '.'], ['NOUN', 'PROPN', 'NOUN', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'NOUN', 'CCONJ', 'NOUN', 'ADP', 'VERB', 'PUNCT']), (['Kendi', 'içlerinde', 'yatak', 'döşek', 'yatası', 'filan', 'olmuyorlar', '.'], ['PRON', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADV', 'VERB', 'PUNCT']), (['Âlem', 'içre', 'muteber', 'bir', 'nesne', 'yok', 'devlet', 'gibi', '/', 'Olmaya', 'devlet', 'cihanda', 'bir', 'nefes', 'sıhhat', 'gibi'], ['NOUN', 'ADV', 'ADJ', 'DET', 'NOUN', 'ADJ', 'NOUN', 'ADP', 'PUNCT', 'VERB', 'NOUN', 'NOUN', 'DET', 'NOUN', 'NOUN', 'ADP']), (['En', 'az', 'ilkokul', 'mezunu', 'olmayanlar', ',', 'kısıtlılar', '.', 'milletvekili', 'seçilemezler', '.'], ['ADV', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'NOUN', 'PUNCT']), (['Dava', 'şu', 'an', 'derdest', '.'], ['NOUN', 'DET', 'NOUN', 'NOUN', 'PUNCT']), (['Şu', 'kuvvetin', ',', 'cevherin', 'sırrını', 'öğrenmek', 'için', 'soruyorum', '.'], ['DET', 'NOUN', 'PUNCT', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'VERB', 'PUNCT']), (['Bakanlar', 'Kurulu', ',', 'kamu', 'personeline', 'ödenecek', 'aylık', 've', 'ücretlerin', 'belirlenmesinde', 'esas', 'alınacak', 'katsayılar', 'ile', 'sözleşme', 'tavan', 'ücretlerini', 'gelecek', 'hafta', 'belirleyecek', '.'], ['NOUN', 'NOUN', 'PUNCT', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'CCONJ', 'NOUN', 'VERB', 'ADJ', 'VERB', 'NOUN', 'CCONJ', 'NOUN', 'ADJ', 'NOUN', 'ADJ', 'NOUN', 'VERB', 'PUNCT']), (['"', 'Yeni', 'anlaşmadan', 'çok', 'memnunuz', '.'], ['PUNCT', 'ADJ', 'NOUN', 'ADV', 'VERB', 'PUNCT']), (['Pandemi', 'yüzünden', 'işinden', 'olmuştu', '.'], ['PROPN', 'ADV', 'NOUN', 'VERB',  ...
# Word to Index: {'YİYECEK': 0, 'İÇECEKLERDEN': 1, '.': 2, 'Başlıca': 3, 'fosforışıl': 4, 'cisimler': 5, 'kalsiyum': 6, 'sülfür': 7, ',': 8, 'radyum': 9, 'stronsiyum': 10, 've': 11, 'çinko': 12, 'sülfürdür': 13, 'İNCİ': 14, 'HANIMDI': 15, 'Bu': 16, 'müthiş': 17, 'yokluğa': 18, 'bu': 19, 'derin': 20, 'acıya': 21, 'tahammül': 22, 'edemiyordum': 23, 'Şirket': 24, 'alımı': 25, "BSN'nin": 26, 'Avrupa': 27, 'makarna': 28, 'piyasasındaki': 29, 'konumunu': 30, 'güçlendiriyor': 31, '2': 32, "Ağustos'ta": 33, "Washington'dan": 34, 'uçuşlar': 35, 'Bana': 36, 'San': 37, "Jose'den": 38, "Phoenix'e": 39, 'olan': 40, 'tüm': 41, 'uçuşları': 42, 'gösterin': 43, '17': 44, 'Haziran’da': 45, 'Oyunun': 46, 'önemli': 47, 'sahnelerinde': 48, 'Bay': 49, 'Boyd': 50, "Shakespeare'nin": 51, 'dinamiğini': 52, 'yakalayan': 53, 'bir': 54, 'firması': 55, 'olduğunu': 56, 'gösteriyor': 57, 'Toz': 58, 'kondurmadığı': 59, 'devletinin': 60, 'kendisini': 61, 'hatırlamasını': 62, 'sabırla': 63, 'bekliyor': 64, 'Serseri': 65, 'güruhunun': 66, 'başlarından': 67, 'düşmeyen': 68, 'siperli': 69, 'sipersiz': 70, 'kapelalarla': 71, 'TAM': 72, 'PUAN': 73, 'VERİYORUM': 74, '6': 75, 'Benimki': 76, 'vehim': 77, 'bedbinlik': 78, 'şiddetli': 79, 'arzularda': 80, 'duyulan': 81, 'kaybetme': 82, 'korkusu': 83, 'Gazi': 84, 'daha': 85, 'çok': 86, 'kuru': 87, 'leblebiyi': 88, 'tercih': 89, 'ederdi': 90, "Nazmiye'nin": 91, 'tepesinden': 92, 'sanki': 93, 'kaynar': 94, 'sular': 95, 'döküldü': 96, 'yo': 97, 'dedi': 98, 'Malzemeler': 99, ':': 100, 'Yanıtlar': 101, 'ABD': 102, 'Nüfus': 103, 'Sayımı': 104, 'verilerine': 105, 'uyacak': 106, 'şekilde': 107, 'yaş': 108, 'cinsiyete': 109, 'göre': 110, 'ağırlıklandırılmıştır': 111, 'Kendi': 112, 'içlerinde': 113, 'yatak': 114, 'döşek': 115, 'yatası': 116, 'filan': 117, 'olmuyorlar': 118, 'Âlem': 119, 'içre': 120, 'muteber': 121, 'nesne': 122, 'yok': 123, 'devlet': 124, 'gibi': 125, '/': 126, 'Olmaya': 127, 'cihanda': 128, 'nefes': 129, 'sıhhat': 130, 'En': 131, 'az': 132, 'ilkokul': 133, 'mezunu': 134, 'olmayanlar': 135, 'kısıtlılar': 136, 'milletvekili': 137, 'seçilemezler': 138, 'Dava': 139, 'şu': 140, 'an': 141, 'derdest': 142, 'Şu': 143, 'kuvvetin': 144, 'cevherin': 145, 'sırrını': 146, 'öğrenmek': 147, 'için': 148, 'soruyorum': 149, 'Bakanlar': 150, 'Kurulu': 151, 'kamu': 152, 'personeline': 153, 'ödenecek': 154, 'aylık': 155, 'ücretlerin': 156, 'belirlenmesinde': 157, 'esas': 158, 'alınacak': 159, 'katsayılar': 160, 'ile': 161, 'sözleşme': 162, 'tavan': 163, 'ücretlerini': 164, 'gelecek': 165, 'hafta': 166, 'belirleyecek': 167, '"': 168, 'Yeni': 169, 'anlaşmadan': 170, 'memnunuz': 171, 'Pandemi': 172, 'yüzünden': 173, 'işinden': 174, 'olmuştu': 175, 'Bir': 176, 'millete': 177, 'yapılabilecek': 178, 'sinsi': 179, 'şeytani': 180, 'hücum': 181, 'onun': 182, 'vicdanından': 183, 'mazisini': 184, 'almak': 185, 'hafızasında': 186, 'etmektir': 187, 'Masadan': 188, 'kalkanlar': 189, 'kalkan': 190, 'lar': 191, 'diğerlerini': 192, 'beklemeden': 193, 'yola': 194, 'koyulmuşlardı': 195, 'bile': 196, 'İbni': 197, 'Haldun': 198, 'külliyatını': 199, 'tetebbu': 200, 'etmeyenlere': 201, 'sırlarını': 202, 'ifşa': 203, 'etmez': 204, 'eser': 205, 'ÜCRETE': 206, 'GÖRE': 207, 'HİZMET': 208, 'KALİTESİ': 209, 'NORMALDİ': 210, 'bana': 211, 'on': 212, 'dört': 213, "Haziran'da": 214, "Denver'den": 215, "Baltimore'ye": 216, 'United': 217, 'uçuşlarını': 218, 'göster': 219, 'FİYATI': 220, 'UYGUNDU': 221, 'AQUAPARKI': 222, 'ÇOK': 223, 'GÜZELDİ': 224, 'Harsco': 225, 'savunma': 226, 'endüstri': 227, 'ticaret': 228, 'inşaat': 229, 'pazarları': 230, 'ürünler': 231, 'üretmektedir': 232, 'Çünkü': 233, '...': 234, 'BEN': 235, 'YAPTIRMADIM': 236, 'BİLMİYORUM': 237, 'ERKEN': 238, 'REZERVASYON': 239, 'DÖNEMLERİNDEN': 240, 'HABERDAR': 241, 'OLMAK': 242, 'İSTİYORUM': 243, 'Masalı': 244, 'bitirir': 245, 'bitirmez': 246, 'de': 247, 'mektupla': 248, 'postalarım': 249, 'DENİZDEN': 250, 'DOLAYI': 251, 'TAVSİYE': 252, 'Seçimlerin': 253, 'tarihi': 254, '7': 255, 'Kasım': 256, 'HER': 257, 'ŞE ...
# Tag to Index: {'NOUN': 0, 'PUNCT': 1, 'ADJ': 2, 'CCONJ': 3, 'VERB': 4, 'PROPN': 5, 'DET': 6, 'NUM': 7, 'PRON': 8, 'ADV': 9, 'INTJ': 10, 'ADP': 11, '_': 12, 'AUX': 13, 'SCONJ': 14, 'X': 15, 'PART': 16}

# %%
n_qubits = 4

model_quantum = LSTMTagger(embedding_dim,
                        hidden_dim,
                        vocab_size=len(word_to_ix),
                        tagset_size=len(tag_to_ix),
                        n_qubits=n_qubits,
                        n_qlayers=2)
# Out:
# Tagger will use Quantum LSTM
# weight_shapes = (n_qlayers, n_qubits) = (2, 4)

# %%
history_quantum = train(model_quantum, n_epochs)
# Out:
# Epoch 1 / 300: Loss = 2.132, Acc = 0.33, LR = 0.100000
# Epoch 2 / 300: Loss = 1.774, Acc = 0.46, LR = 0.100000
# Epoch 3 / 300: Loss = 1.673, Acc = 0.46, LR = 0.100000
# Epoch 4 / 300: Loss = 1.655, Acc = 0.47, LR = 0.100000
# Epoch 5 / 300: Loss = 1.640, Acc = 0.47, LR = 0.100000
# Epoch 6 / 300: Loss = 1.624, Acc = 0.47, LR = 0.100000
# Epoch 7 / 300: Loss = 1.632, Acc = 0.47, LR = 0.080000
# Epoch 8 / 300: Loss = 1.733, Acc = 0.45, LR = 0.080000
# Epoch 9 / 300: Loss = 1.627, Acc = 0.47, LR = 0.080000
# Epoch 10 / 300: Loss = 1.569, Acc = 0.49, LR = 0.080000
# Epoch 11 / 300: Loss = 1.545, Acc = 0.50, LR = 0.080000
# Epoch 12 / 300: Loss = 1.595, Acc = 0.49, LR = 0.080000
# Epoch 13 / 300: Loss = 1.594, Acc = 0.49, LR = 0.080000
# Epoch 14 / 300: Loss = 1.513, Acc = 0.51, LR = 0.064000
# Epoch 15 / 300: Loss = 1.569, Acc = 0.49, LR = 0.064000
# Epoch 16 / 300: Loss = 1.506, Acc = 0.50, LR = 0.064000
# Epoch 17 / 300: Loss = 1.473, Acc = 0.51, LR = 0.064000
# Epoch 18 / 300: Loss = 1.440, Acc = 0.52, LR = 0.064000
# Epoch 19 / 300: Loss = 1.408, Acc = 0.53, LR = 0.064000
# Epoch 20 / 300: Loss = 1.393, Acc = 0.53, LR = 0.064000
# Epoch 21 / 300: Loss = 1.371, Acc = 0.53, LR = 0.051200
# Epoch 22 / 300: Loss = 1.341, Acc = 0.54, LR = 0.051200
# Epoch 23 / 300: Loss = 1.320, Acc = 0.54, LR = 0.051200
# Epoch 24 / 300: Loss = 1.298, Acc = 0.55, LR = 0.051200
# Epoch 25 / 300: Loss = 1.279, Acc = 0.56, LR = 0.051200
# Epoch 26 / 300: Loss = 1.263, Acc = 0.56, LR = 0.051200
# Epoch 27 / 300: Loss = 1.243, Acc = 0.57, LR = 0.051200
# Epoch 28 / 300: Loss = 1.229, Acc = 0.57, LR = 0.040960
# Epoch 29 / 300: Loss = 1.197, Acc = 0.58, LR = 0.040960
# Epoch 30 / 300: Loss = 1.172, Acc = 0.59, LR = 0.040960
# Epoch 31 / 300: Loss = 1.154, Acc = 0.60, LR = 0.040960
# Epoch 32 / 300: Loss = 1.133, Acc = 0.60, LR = 0.040960
# Epoch 33 / 300: Loss = 1.114, Acc = 0.61, LR = 0.040960
# Epoch 34 / 300: Loss = 1.098, Acc = 0.62, LR = 0.040960
# Epoch 35 / 300: Loss = 1.083, Acc = 0.62, LR = 0.032768
# Epoch 36 / 300: Loss = 1.052, Acc = 0.63, LR = 0.032768
# Epoch 37 / 300: Loss = 1.034, Acc = 0.64, LR = 0.032768
# Epoch 38 / 300: Loss = 1.015, Acc = 0.65, LR = 0.032768
# Epoch 39 / 300: Loss = 1.002, Acc = 0.65, LR = 0.032768
# Epoch 40 / 300: Loss = 0.984, Acc = 0.66, LR = 0.032768
# Epoch 41 / 300: Loss = 0.970, Acc = 0.66, LR = 0.032768
# Epoch 42 / 300: Loss = 0.963, Acc = 0.67, LR = 0.026214
# Epoch 43 / 300: Loss = 0.943, Acc = 0.67, LR = 0.026214
# Epoch 44 / 300: Loss = 0.930, Acc = 0.68, LR = 0.026214
# Epoch 45 / 300: Loss = 0.918, Acc = 0.68, LR = 0.026214
# Epoch 46 / 300: Loss = 0.907, Acc = 0.69, LR = 0.026214
# Epoch 47 / 300: Loss = 0.896, Acc = 0.69, LR = 0.026214
# Epoch 48 / 300: Loss = 0.886, Acc = 0.69, LR = 0.026214
# Epoch 49 / 300: Loss = 0.874, Acc = 0.70, LR = 0.020972
# Epoch 50 / 300: Loss = 0.862, Acc = 0.70, LR = 0.020972
# Epoch 51 / 300: Loss = 0.853, Acc = 0.71, LR = 0.020972
# Epoch 52 / 300: Loss = 0.841, Acc = 0.71, LR = 0.020972
# Epoch 53 / 300: Loss = 0.835, Acc = 0.71, LR = 0.020972
# Epoch 54 / 300: Loss = 0.829, Acc = 0.71, LR = 0.020972
# Epoch 55 / 300: Loss = 0.820, Acc = 0.72, LR = 0.020972
# Epoch 56 / 300: Loss = 0.814, Acc = 0.72, LR = 0.016777
# Epoch 57 / 300: Loss = 0.802, Acc = 0.72, LR = 0.016777
# Epoch 58 / 300: Loss = 0.793, Acc = 0.72, LR = 0.016777
# Epoch 59 / 300: Loss = 0.787, Acc = 0.73, LR = 0.016777
# Epoch 60 / 300: Loss = 0.781, Acc = 0.73, LR = 0.016777
# Epoch 61 / 300: Loss = 0.773, Acc = 0.73, LR = 0.016777
# Epoch 62 / 300: Loss = 0.767, Acc = 0.73, LR = 0.016777
# Epoch 63 / 300: Loss = 0.761, Acc = 0.74, LR = 0.013422
# Epoch 64 / 300: Loss = 0.754, Acc = 0.74, LR = 0.013422
# Epoch 65 / 300: Loss = 0.747, Acc = 0.74, LR = 0.013422
# Epoch 66 / 300: Loss = 0.742, Acc = 0.74, LR = 0.013422
# Epoch 67 / 300: Loss = 0.739, Acc = 0.75, LR = 0.013422
# Epoch 68 / 300: Loss = 0.733, Acc = 0.75, LR = 0.013422
# Epoch 69 / 300: Loss = 0.728, Acc = 0.75, LR = 0.013422
# Epoch 70 / 300: Loss = 0.724, Acc = 0.75, LR = 0.010737
# Epoch 71 / 300: Loss = 0.718, Acc = 0.76, LR = 0.010737
# Epoch 72 / 300: Loss = 0.713, Acc = 0.76, LR = 0.010737
# Epoch 73 / 300: Loss = 0.709, Acc = 0.76, LR = 0.010737
# Epoch 74 / 300: Loss = 0.705, Acc = 0.76, LR = 0.010737
# Epoch 75 / 300: Loss = 0.702, Acc = 0.76, LR = 0.010737
# Epoch 76 / 300: Loss = 0.698, Acc = 0.76, LR = 0.010737
# Epoch 77 / 300: Loss = 0.694, Acc = 0.76, LR = 0.008590
# Epoch 78 / 300: Loss = 0.690, Acc = 0.77, LR = 0.008590
# Epoch 79 / 300: Loss = 0.687, Acc = 0.77, LR = 0.008590
# Epoch 80 / 300: Loss = 0.683, Acc = 0.77, LR = 0.008590
# Epoch 81 / 300: Loss = 0.680, Acc = 0.77, LR = 0.008590
# Epoch 82 / 300: Loss = 0.678, Acc = 0.77, LR = 0.008590
# Epoch 83 / 300: Loss = 0.675, Acc = 0.77, LR = 0.008590
# Epoch 84 / 300: Loss = 0.672, Acc = 0.77, LR = 0.006872
# Epoch 85 / 300: Loss = 0.669, Acc = 0.77, LR = 0.006872
# Epoch 86 / 300: Loss = 0.666, Acc = 0.77, LR = 0.006872
# Epoch 87 / 300: Loss = 0.663, Acc = 0.77, LR = 0.006872
# Epoch 88 / 300: Loss = 0.662, Acc = 0.78, LR = 0.006872
# Epoch 89 / 300: Loss = 0.659, Acc = 0.78, LR = 0.006872
# Epoch 90 / 300: Loss = 0.656, Acc = 0.78, LR = 0.006872
# Epoch 91 / 300: Loss = 0.655, Acc = 0.78, LR = 0.005498
# Epoch 92 / 300: Loss = 0.651, Acc = 0.78, LR = 0.005498
# Epoch 93 / 300: Loss = 0.649, Acc = 0.78, LR = 0.005498
# Epoch 94 / 300: Loss = 0.647, Acc = 0.78, LR = 0.005498
# Epoch 95 / 300: Loss = 0.646, Acc = 0.78, LR = 0.005498
# Epoch 96 / 300: Loss = 0.644, Acc = 0.78, LR = 0.005498
# Epoch 97 / 300: Loss = 0.642, Acc = 0.78, LR = 0.005498
# Epoch 98 / 300: Loss = 0.640, Acc = 0.78, LR = 0.004398
# Epoch 99 / 300: Loss = 0.638, Acc = 0.78, LR = 0.004398
# Epoch 100 / 300: Loss = 0.637, Acc = 0.79, LR = 0.004398
# Epoch 101 / 300: Loss = 0.635, Acc = 0.79, LR = 0.004398
# Epoch 102 / 300: Loss = 0.634, Acc = 0.79, LR = 0.004398
# Epoch 103 / 300: Loss = 0.632, Acc = 0.79, LR = 0.004398
# Epoch 104 / 300: Loss = 0.631, Acc = 0.79, LR = 0.004398
# Epoch 105 / 300: Loss = 0.630, Acc = 0.79, LR = 0.003518
# Epoch 106 / 300: Loss = 0.628, Acc = 0.79, LR = 0.003518
# Epoch 107 / 300: Loss = 0.627, Acc = 0.79, LR = 0.003518
# Epoch 108 / 300: Loss = 0.626, Acc = 0.79, LR = 0.003518
# Epoch 109 / 300: Loss = 0.625, Acc = 0.79, LR = 0.003518
# Epoch 110 / 300: Loss = 0.624, Acc = 0.79, LR = 0.003518
# Epoch 111 / 300: Loss = 0.622, Acc = 0.79, LR = 0.003518
# Epoch 112 / 300: Loss = 0.621, Acc = 0.79, LR = 0.002815
# Epoch 113 / 300: Loss = 0.620, Acc = 0.79, LR = 0.002815
# Epoch 114 / 300: Loss = 0.619, Acc = 0.79, LR = 0.002815
# Epoch 115 / 300: Loss = 0.618, Acc = 0.79, LR = 0.002815
# Epoch 116 / 300: Loss = 0.617, Acc = 0.79, LR = 0.002815
# Epoch 117 / 300: Loss = 0.617, Acc = 0.79, LR = 0.002815
# Epoch 118 / 300: Loss = 0.616, Acc = 0.79, LR = 0.002815
# Epoch 119 / 300: Loss = 0.615, Acc = 0.79, LR = 0.002252
# Epoch 120 / 300: Loss = 0.614, Acc = 0.79, LR = 0.002252
# Epoch 121 / 300: Loss = 0.613, Acc = 0.79, LR = 0.002252
# Epoch 122 / 300: Loss = 0.613, Acc = 0.80, LR = 0.002252
# Epoch 123 / 300: Loss = 0.612, Acc = 0.80, LR = 0.002252
# Epoch 124 / 300: Loss = 0.611, Acc = 0.80, LR = 0.002252
# Epoch 125 / 300: Loss = 0.610, Acc = 0.80, LR = 0.002252
# Epoch 126 / 300: Loss = 0.610, Acc = 0.80, LR = 0.001801
# Epoch 127 / 300: Loss = 0.609, Acc = 0.80, LR = 0.001801
# Epoch 128 / 300: Loss = 0.608, Acc = 0.80, LR = 0.001801
# Epoch 129 / 300: Loss = 0.608, Acc = 0.80, LR = 0.001801
# Epoch 130 / 300: Loss = 0.607, Acc = 0.80, LR = 0.001801
# Epoch 131 / 300: Loss = 0.607, Acc = 0.80, LR = 0.001801
# Epoch 132 / 300: Loss = 0.606, Acc = 0.80, LR = 0.001801
# Epoch 133 / 300: Loss = 0.606, Acc = 0.80, LR = 0.001441
# Epoch 134 / 300: Loss = 0.605, Acc = 0.80, LR = 0.001441
# Epoch 135 / 300: Loss = 0.605, Acc = 0.80, LR = 0.001441
# Epoch 136 / 300: Loss = 0.604, Acc = 0.80, LR = 0.001441
# Epoch 137 / 300: Loss = 0.604, Acc = 0.80, LR = 0.001441
# Epoch 138 / 300: Loss = 0.603, Acc = 0.80, LR = 0.001441
# Epoch 139 / 300: Loss = 0.603, Acc = 0.80, LR = 0.001441
# Epoch 140 / 300: Loss = 0.602, Acc = 0.80, LR = 0.001153
# Epoch 141 / 300: Loss = 0.602, Acc = 0.80, LR = 0.001153
# Epoch 142 / 300: Loss = 0.601, Acc = 0.80, LR = 0.001153
# Epoch 143 / 300: Loss = 0.601, Acc = 0.80, LR = 0.001153
# Epoch 144 / 300: Loss = 0.601, Acc = 0.80, LR = 0.001153
# Epoch 145 / 300: Loss = 0.600, Acc = 0.80, LR = 0.001153
# Epoch 146 / 300: Loss = 0.600, Acc = 0.80, LR = 0.001153
# Epoch 147 / 300: Loss = 0.600, Acc = 0.80, LR = 0.000922
# Epoch 148 / 300: Loss = 0.599, Acc = 0.80, LR = 0.000922
# Epoch 149 / 300: Loss = 0.599, Acc = 0.80, LR = 0.000922
# Epoch 150 / 300: Loss = 0.599, Acc = 0.80, LR = 0.000922
# Epoch 151 / 300: Loss = 0.598, Acc = 0.80, LR = 0.000922
# Epoch 152 / 300: Loss = 0.598, Acc = 0.80, LR = 0.000922
# Epoch 153 / 300: Loss = 0.598, Acc = 0.80, LR = 0.000922
# Epoch 154 / 300: Loss = 0.597, Acc = 0.80, LR = 0.000738
# Epoch 155 / 300: Loss = 0.597, Acc = 0.80, LR = 0.000738
# Epoch 156 / 300: Loss = 0.597, Acc = 0.80, LR = 0.000738
# Epoch 157 / 300: Loss = 0.596, Acc = 0.80, LR = 0.000738
# Epoch 158 / 300: Loss = 0.596, Acc = 0.80, LR = 0.000738
# Epoch 159 / 300: Loss = 0.596, Acc = 0.80, LR = 0.000738
# Epoch 160 / 300: Loss = 0.596, Acc = 0.80, LR = 0.000738
# Epoch 161 / 300: Loss = 0.595, Acc = 0.80, LR = 0.000590
# Epoch 162 / 300: Loss = 0.595, Acc = 0.80, LR = 0.000590
# Epoch 163 / 300: Loss = 0.595, Acc = 0.80, LR = 0.000590
# Epoch 164 / 300: Loss = 0.595, Acc = 0.80, LR = 0.000590
# Epoch 165 / 300: Loss = 0.595, Acc = 0.80, LR = 0.000590
# Epoch 166 / 300: Loss = 0.594, Acc = 0.80, LR = 0.000590
# Epoch 167 / 300: Loss = 0.594, Acc = 0.80, LR = 0.000590
# Epoch 168 / 300: Loss = 0.594, Acc = 0.80, LR = 0.000472
# Epoch 169 / 300: Loss = 0.594, Acc = 0.80, LR = 0.000472
# Epoch 170 / 300: Loss = 0.594, Acc = 0.80, LR = 0.000472
# Epoch 171 / 300: Loss = 0.593, Acc = 0.80, LR = 0.000472
# Epoch 172 / 300: Loss = 0.593, Acc = 0.80, LR = 0.000472
# Epoch 173 / 300: Loss = 0.593, Acc = 0.80, LR = 0.000472
# Epoch 174 / 300: Loss = 0.593, Acc = 0.80, LR = 0.000472
# Epoch 175 / 300: Loss = 0.593, Acc = 0.80, LR = 0.000378
# Epoch 176 / 300: Loss = 0.593, Acc = 0.80, LR = 0.000378
# Epoch 177 / 300: Loss = 0.592, Acc = 0.80, LR = 0.000378
# Epoch 178 / 300: Loss = 0.592, Acc = 0.80, LR = 0.000378
# Epoch 179 / 300: Loss = 0.592, Acc = 0.80, LR = 0.000378
# Epoch 180 / 300: Loss = 0.592, Acc = 0.80, LR = 0.000378
# Epoch 181 / 300: Loss = 0.592, Acc = 0.80, LR = 0.000378
# Epoch 182 / 300: Loss = 0.592, Acc = 0.80, LR = 0.000302
# Epoch 183 / 300: Loss = 0.592, Acc = 0.80, LR = 0.000302
# Epoch 184 / 300: Loss = 0.592, Acc = 0.80, LR = 0.000302
# Epoch 185 / 300: Loss = 0.591, Acc = 0.80, LR = 0.000302
# Epoch 186 / 300: Loss = 0.591, Acc = 0.80, LR = 0.000302
# Epoch 187 / 300: Loss = 0.591, Acc = 0.80, LR = 0.000302
# Epoch 188 / 300: Loss = 0.591, Acc = 0.80, LR = 0.000302
# Epoch 189 / 300: Loss = 0.591, Acc = 0.80, LR = 0.000242
# Epoch 190 / 300: Loss = 0.591, Acc = 0.80, LR = 0.000242
# Epoch 191 / 300: Loss = 0.591, Acc = 0.80, LR = 0.000242
# Epoch 192 / 300: Loss = 0.591, Acc = 0.80, LR = 0.000242
# Epoch 193 / 300: Loss = 0.591, Acc = 0.80, LR = 0.000242
# Epoch 194 / 300: Loss = 0.591, Acc = 0.80, LR = 0.000242
# Epoch 195 / 300: Loss = 0.590, Acc = 0.80, LR = 0.000242
# Epoch 196 / 300: Loss = 0.590, Acc = 0.80, LR = 0.000193
# Epoch 197 / 300: Loss = 0.590, Acc = 0.80, LR = 0.000193
# Epoch 198 / 300: Loss = 0.590, Acc = 0.80, LR = 0.000193
# Epoch 199 / 300: Loss = 0.590, Acc = 0.80, LR = 0.000193
# Epoch 200 / 300: Loss = 0.590, Acc = 0.80, LR = 0.000193
# Epoch 201 / 300: Loss = 0.590, Acc = 0.80, LR = 0.000193
# Epoch 202 / 300: Loss = 0.590, Acc = 0.80, LR = 0.000193
# Epoch 203 / 300: Loss = 0.590, Acc = 0.80, LR = 0.000155
# Epoch 204 / 300: Loss = 0.590, Acc = 0.80, LR = 0.000155
# Epoch 205 / 300: Loss = 0.590, Acc = 0.80, LR = 0.000155
# Epoch 206 / 300: Loss = 0.590, Acc = 0.80, LR = 0.000155
# Epoch 207 / 300: Loss = 0.590, Acc = 0.80, LR = 0.000155
# Epoch 208 / 300: Loss = 0.590, Acc = 0.80, LR = 0.000155
# Epoch 209 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000155
# Epoch 210 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000124
# Epoch 211 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000124
# Epoch 212 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000124
# Epoch 213 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000124
# Epoch 214 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000124
# Epoch 215 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000124
# Epoch 216 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000124
# Epoch 217 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000099
# Epoch 218 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000099
# Epoch 219 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000099
# Epoch 220 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000099
# Epoch 221 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000099
# Epoch 222 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000099
# Epoch 223 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000099
# Epoch 224 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000079
# Epoch 225 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000079
# Epoch 226 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000079
# Epoch 227 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000079
# Epoch 228 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000079
# Epoch 229 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000079
# Epoch 230 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000079
# Epoch 231 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000063
# Epoch 232 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000063
# Epoch 233 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000063
# Epoch 234 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000063
# Epoch 235 / 300: Loss = 0.589, Acc = 0.80, LR = 0.000063
# Epoch 236 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000063
# Epoch 237 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000063
# Epoch 238 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000051
# Epoch 239 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000051
# Epoch 240 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000051
# Epoch 241 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000051
# Epoch 242 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000051
# Epoch 243 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000051
# Epoch 244 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000051
# Epoch 245 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000041
# Epoch 246 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000041
# Epoch 247 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000041
# Epoch 248 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000041
# Epoch 249 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000041
# Epoch 250 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000041
# Epoch 251 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000041
# Epoch 252 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000032
# Epoch 253 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000032
# Epoch 254 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000032
# Epoch 255 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000032
# Epoch 256 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000032
# Epoch 257 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000032
# Epoch 258 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000032
# Epoch 259 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000026
# Epoch 260 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000026
# Epoch 261 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000026
# Epoch 262 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000026
# Epoch 263 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000026
# Epoch 264 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000026
# Epoch 265 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000026
# Epoch 266 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000021
# Epoch 267 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000021
# Epoch 268 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000021
# Epoch 269 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000021
# Epoch 270 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000021
# Epoch 271 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000021
# Epoch 272 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000021
# Epoch 273 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000017
# Epoch 274 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000017
# Epoch 275 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000017
# Epoch 276 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000017
# Epoch 277 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000017
# Epoch 278 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000017
# Epoch 279 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000017
# Epoch 280 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000013
# Epoch 281 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000013
# Epoch 282 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000013
# Epoch 283 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000013
# Epoch 284 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000013
# Epoch 285 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000013
# Epoch 286 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000013
# Epoch 287 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000011
# Epoch 288 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000011
# Epoch 289 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000011
# Epoch 290 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000011
# Epoch 291 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000011
# Epoch 292 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000011
# Epoch 293 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000011
# Epoch 294 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000009
# Epoch 295 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000009
# Epoch 296 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000009
# Epoch 297 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000009
# Epoch 298 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000009
# Epoch 299 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000009
# Epoch 300 / 300: Loss = 0.588, Acc = 0.80, LR = 0.000009

# %%
torch.save(model_quantum.state_dict(), "qlstm_tagger_turkish.pth")

# %%
print_result(model_quantum)
# Out:
# Sentence:  ['YİYECEK', 'İÇECEKLERDEN', '.']
# Labels:    ['NOUN', 'NOUN', 'PUNCT']
# Predicted: ['_', '_', 'ADJ']
