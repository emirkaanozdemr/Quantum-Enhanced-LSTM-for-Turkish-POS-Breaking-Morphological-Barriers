# %% [markdown]
# # A Quantum-Enhanced LSTM Layer

# %% [markdown]
# Kuantum Makine Öğrenmesinde şimdiye kadar yeterince araştırılmamış bir alan, bilgisayarlara yazılı metni okuma, yazma ve bir dereceye kadar anlama yeteneği veren Yapay Zekâ'nın alt alanı olan Doğal Dil İşleme'dir (NLP).
#
# Belgeler genellikle kelime dizileri olarak sunulduğundan, tarihsel olarak bu tür verileri işlemek için en başarılı tekniklerden biri Tekrarlayan Sinir Ağı mimarisi ve özellikle Uzun Kısa Süreli Bellek (LSTM) adı verilen bir varyant olmuştur. LSTM'ler, makinelerin Transformatör ağlarının ortaya çıkışına kadar en son teknoloji doğrulukla çeviriler, sınıflandırmalar ve niyet tespiti yapmalarına olanak sağladı. Yine de, iyi kuantum hesaplamanın alana ne getirebileceğini görmek için LSTM'leri araştırmak en azından eğitim açısından ilginçtir. Daha ayrıntılı bir tartışma için lütfen Chen, Yoo ve Fang'ın "Kuantum Uzun Kısa Süreli Bellek" (arXiv:2009.01783) ve J. Bausch'un "Tekrarlayan Kuantum Sinir Ağları" (arXiv:2006.14619) makalelerine bakın.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from quantum_lstm import QLSTM #./quantum_lstm.py
# Out:
# d:\Programlar\Anaconda3\lib\site-packages\_distutils_hack\__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %%
import pandas as pd
df=pd.read_csv('turkish_ud_741.5K.csv')
# Universal Dependencies Veri Seti Türkçe

# %%
df.head()
# Out:
#                                             Sentence  \
# 0                      1936 yılındayız yılında yız .
# 1    Adeta kendimden geçmiş bir haldeyim halde yim .
# 2  O nasıl derse desin uğraştığı sanatın kendisin...
# 3  Ahmed Rasim , Büyükada'ya gidip birkaç gün kal...
# 4             Rüzgâr yine güçlü esiyordu esiyor du .
#
#                                        UPOS Sequence
# 0                               NUM _ NOUN AUX PUNCT
# 1                 ADV PRON VERB DET _ NOUN AUX PUNCT
# 2  PRON ADV VERB VERB VERB NOUN PRON NOUN VERB VE...
# 3  PROPN PROPN PUNCT PROPN VERB DET NOUN VERB _ V...
# 4                      NOUN ADV ADV _ VERB AUX PUNCT

# %%
sequences = df['UPOS Sequence'].str.split(expand=True).stack().unique()

print(sequences)
# Out:
# ['NUM' '_' 'NOUN' 'AUX' 'PUNCT' 'ADV' 'PRON' 'VERB' 'DET' 'PROPN' 'ADJ'
#  'CCONJ' 'ADP' 'PART' 'SCONJ' 'INTJ' 'X' 'SYM']

# %%
tag_to_ix = {'_': 0, 'ADJ': 1, 'ADP': 2, 'ADV': 3, 'AUX': 4, 'CCONJ': 5, 'DET': 6, 'INTJ': 7, 'NOUN': 8, 'NUM': 9, 'PART': 10, 'PRON': 11, 'PROPN': 12, 'PUNCT': 13, 'SCONJ': 14, 'VERB': 15, 'X': 16, 'SYM':17} # Assign each tag with a unique index
ix_to_tag = {i:k for k,i in tag_to_ix.items()}

# %% [markdown]
# Aşağıdaki fonksiyon cümleyi kelimelere ayırır ve etiketi her kelimeyle eşleştirir.

# %%
def prepare_sequence(seq, to_ix):
    idxs = [to_ix[w] for w in seq]
    return torch.tensor(idxs, dtype=torch.long)

# %% [markdown]
# Aşağıdaki döngü eğitim veri setini oluşturur.

# %%
training_data = []
word_to_ix = {}
tag_to_ix = {}

for _, row in df.iterrows():
    words = row['Sentence'].split()
    tags = row['UPOS Sequence'].split()
    training_data.append((words, tags))
    for word in words:
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)
    for tag in tags:
        if tag not in tag_to_ix:
            tag_to_ix[tag] = len(tag_to_ix)

print(f"Training Data: {training_data}")
print(f"Word to Index: {word_to_ix}")
print(f"Tag to Index: {tag_to_ix}")
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Fikir, her kelime için bir tane olmak üzere gizli vektör dizisini [h_0, h_1, h_2, h_3, h_4] çıktısı verecek olan iki diziyi LSTM'den geçirmektir. Her kelimenin bir belirleyici, isim veya fiil olma olasılığını hesaplamak için LSTM'nin çıktılarına yoğun bir katman "head" eklenir.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class LSTMTagger(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size, pretrained_embeddings=None,
                 n_qubits=0, num_layers=4, n_qlayers=4, freeze_embeddings=False):
        super(LSTMTagger, self).__init__()
        self.hidden_dim = hidden_dim


        if pretrained_embeddings is not None:

            self.word_embeddings = nn.Embedding.from_pretrained(pretrained_embeddings, freeze=freeze_embeddings)
        else:

            self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)


        if n_qubits > 0:
            print("Tagger will use Quantum LSTM")
            self.lstm = QLSTM(embedding_dim, hidden_dim, n_qubits=n_qubits, n_qlayers=n_qlayers)
        else:
            print("Tagger will use Classical LSTM")
            self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=num_layers, batch_first=True)


        self.hidden2tag = nn.Linear(hidden_dim, tagset_size)

    def forward(self, sentence):
        embeds = self.word_embeddings(sentence)
        lstm_out, _ = self.lstm(embeds.view(len(sentence), 1, -1))
        tag_logits = self.hidden2tag(lstm_out.view(len(sentence), -1))
        tag_scores = F.log_softmax(tag_logits, dim=1)
        return tag_scores

# %%
embedding_dim = 8
hidden_dim = 6
n_epochs = 300

# %%
model_classical = LSTMTagger(embedding_dim,
                        hidden_dim,
                        vocab_size=len(word_to_ix),
                        tagset_size=len(tag_to_ix),
                        n_qubits=0)
# Out:
# Tagger will use Classical LSTM

# %% [markdown]
# ## Training

# %% [markdown]
# Following the example from the PyTorch website, we train the two networks (classical and quantum LSTM) for 300 epochs.

# %%
def train(model, n_epochs):
    loss_function = nn.NLLLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.1)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.8)

    history = {
        'loss': [],
        'acc': []
    }
    for epoch in range(n_epochs):
        losses = []
        preds = []
        targets = []
        for sentence, tags in training_data:
            model.zero_grad()
            sentence_in = prepare_sequence(sentence, word_to_ix)
            labels = prepare_sequence(tags, tag_to_ix)

            tag_scores = model(sentence_in)
            loss = loss_function(tag_scores, labels)
            loss.backward()
            optimizer.step()
            losses.append(float(loss))

            probs = torch.softmax(tag_scores, dim=-1)
            preds.append(probs.argmax(dim=-1))
            targets.append(labels)

        avg_loss = np.mean(losses)
        history['loss'].append(avg_loss)

        preds = torch.cat(preds)
        targets = torch.cat(targets)
        corrects = (preds == targets)
        accuracy = corrects.sum().float() / float(targets.size(0))
        history['acc'].append(accuracy)


        scheduler.step()

        print(f"Epoch {epoch+1} / {n_epochs}: Loss = {avg_loss:.3f}, Acc = {accuracy:.2f}, LR = {scheduler.get_last_lr()[0]:.6f}")

    return history

# %%
history_classical = train(model_classical, n_epochs)
# Out:
# Epoch 1 / 300: Loss = 1.560, Acc = 0.48, LR = 0.100000
# Epoch 2 / 300: Loss = 1.284, Acc = 0.56, LR = 0.100000
# Epoch 3 / 300: Loss = 1.113, Acc = 0.61, LR = 0.100000
# Epoch 4 / 300: Loss = 1.013, Acc = 0.64, LR = 0.100000
# Epoch 5 / 300: Loss = 0.984, Acc = 0.65, LR = 0.100000
# Epoch 6 / 300: Loss = 0.905, Acc = 0.67, LR = 0.100000
# Epoch 7 / 300: Loss = 0.879, Acc = 0.68, LR = 0.080000
# Epoch 8 / 300: Loss = 0.860, Acc = 0.69, LR = 0.080000
# Epoch 9 / 300: Loss = 0.876, Acc = 0.69, LR = 0.080000
# Epoch 10 / 300: Loss = 0.848, Acc = 0.70, LR = 0.080000
# Epoch 11 / 300: Loss = 0.841, Acc = 0.71, LR = 0.080000
# Epoch 12 / 300: Loss = 0.854, Acc = 0.71, LR = 0.080000
# Epoch 13 / 300: Loss = 0.849, Acc = 0.71, LR = 0.080000
# Epoch 14 / 300: Loss = 0.954, Acc = 0.68, LR = 0.064000
# Epoch 15 / 300: Loss = 0.997, Acc = 0.66, LR = 0.064000
# Epoch 16 / 300: Loss = 0.830, Acc = 0.72, LR = 0.064000
# Epoch 17 / 300: Loss = 0.791, Acc = 0.74, LR = 0.064000
# Epoch 18 / 300: Loss = 0.794, Acc = 0.73, LR = 0.064000
# Epoch 19 / 300: Loss = 1.004, Acc = 0.65, LR = 0.064000
# Epoch 20 / 300: Loss = 1.049, Acc = 0.64, LR = 0.064000
# Epoch 21 / 300: Loss = 0.895, Acc = 0.69, LR = 0.051200
# Epoch 22 / 300: Loss = 0.762, Acc = 0.74, LR = 0.051200
# Epoch 23 / 300: Loss = 0.732, Acc = 0.75, LR = 0.051200
# Epoch 24 / 300: Loss = 0.710, Acc = 0.76, LR = 0.051200
# Epoch 25 / 300: Loss = 0.694, Acc = 0.77, LR = 0.051200
# Epoch 26 / 300: Loss = 0.770, Acc = 0.74, LR = 0.051200
# Epoch 27 / 300: Loss = 1.018, Acc = 0.65, LR = 0.051200
# Epoch 28 / 300: Loss = 0.842, Acc = 0.73, LR = 0.040960
# Epoch 29 / 300: Loss = 0.771, Acc = 0.76, LR = 0.040960
# Epoch 30 / 300: Loss = 0.985, Acc = 0.66, LR = 0.040960
# Epoch 31 / 300: Loss = 0.772, Acc = 0.75, LR = 0.040960
# Epoch 32 / 300: Loss = 0.744, Acc = 0.76, LR = 0.040960
# Epoch 33 / 300: Loss = 0.741, Acc = 0.76, LR = 0.040960
# Epoch 34 / 300: Loss = 0.730, Acc = 0.77, LR = 0.040960
# Epoch 35 / 300: Loss = 0.969, Acc = 0.68, LR = 0.032768
# Epoch 36 / 300: Loss = 0.734, Acc = 0.77, LR = 0.032768
# Epoch 37 / 300: Loss = 0.689, Acc = 0.78, LR = 0.032768
# Epoch 38 / 300: Loss = 0.673, Acc = 0.78, LR = 0.032768
# Epoch 39 / 300: Loss = 0.669, Acc = 0.79, LR = 0.032768
# Epoch 40 / 300: Loss = 0.648, Acc = 0.79, LR = 0.032768
# Epoch 41 / 300: Loss = 0.704, Acc = 0.77, LR = 0.032768
# Epoch 42 / 300: Loss = 0.812, Acc = 0.73, LR = 0.026214
# Epoch 43 / 300: Loss = 0.762, Acc = 0.75, LR = 0.026214
# Epoch 44 / 300: Loss = 0.714, Acc = 0.77, LR = 0.026214
# Epoch 45 / 300: Loss = 0.777, Acc = 0.75, LR = 0.026214
# Epoch 46 / 300: Loss = 0.808, Acc = 0.74, LR = 0.026214
# Epoch 47 / 300: Loss = 0.799, Acc = 0.73, LR = 0.026214
# Epoch 48 / 300: Loss = 0.725, Acc = 0.76, LR = 0.026214
# Epoch 49 / 300: Loss = 0.888, Acc = 0.69, LR = 0.020972
# Epoch 50 / 300: Loss = 0.707, Acc = 0.77, LR = 0.020972
# Epoch 51 / 300: Loss = 0.645, Acc = 0.79, LR = 0.020972
# Epoch 52 / 300: Loss = 0.648, Acc = 0.79, LR = 0.020972
# Epoch 53 / 300: Loss = 0.695, Acc = 0.78, LR = 0.020972
# Epoch 54 / 300: Loss = 0.746, Acc = 0.76, LR = 0.020972
# Epoch 55 / 300: Loss = 0.694, Acc = 0.77, LR = 0.020972
# Epoch 56 / 300: Loss = 0.719, Acc = 0.76, LR = 0.016777
# Epoch 57 / 300: Loss = 0.620, Acc = 0.80, LR = 0.016777
# Epoch 58 / 300: Loss = 0.626, Acc = 0.80, LR = 0.016777
# Epoch 59 / 300: Loss = 0.637, Acc = 0.79, LR = 0.016777
# Epoch 60 / 300: Loss = 0.671, Acc = 0.78, LR = 0.016777
# Epoch 61 / 300: Loss = 0.677, Acc = 0.78, LR = 0.016777
# Epoch 62 / 300: Loss = 0.754, Acc = 0.75, LR = 0.016777
# Epoch 63 / 300: Loss = 0.722, Acc = 0.77, LR = 0.013422
# Epoch 64 / 300: Loss = 0.637, Acc = 0.80, LR = 0.013422
# Epoch 65 / 300: Loss = 0.615, Acc = 0.80, LR = 0.013422
# Epoch 66 / 300: Loss = 0.671, Acc = 0.78, LR = 0.013422
# Epoch 67 / 300: Loss = 0.769, Acc = 0.74, LR = 0.013422
# Epoch 68 / 300: Loss = 0.684, Acc = 0.78, LR = 0.013422
# Epoch 69 / 300: Loss = 0.666, Acc = 0.79, LR = 0.013422
# Epoch 70 / 300: Loss = 0.688, Acc = 0.78, LR = 0.010737
# Epoch 71 / 300: Loss = 0.718, Acc = 0.77, LR = 0.010737
# Epoch 72 / 300: Loss = 0.686, Acc = 0.78, LR = 0.010737
# Epoch 73 / 300: Loss = 0.978, Acc = 0.68, LR = 0.010737
# Epoch 74 / 300: Loss = 0.711, Acc = 0.77, LR = 0.010737
# Epoch 75 / 300: Loss = 0.650, Acc = 0.80, LR = 0.010737
# Epoch 76 / 300: Loss = 0.707, Acc = 0.78, LR = 0.010737
# Epoch 77 / 300: Loss = 0.943, Acc = 0.68, LR = 0.008590
# Epoch 78 / 300: Loss = 0.799, Acc = 0.73, LR = 0.008590
# Epoch 79 / 300: Loss = 0.763, Acc = 0.74, LR = 0.008590
# Epoch 80 / 300: Loss = 0.745, Acc = 0.75, LR = 0.008590
# Epoch 81 / 300: Loss = 0.730, Acc = 0.75, LR = 0.008590
# Epoch 82 / 300: Loss = 0.716, Acc = 0.76, LR = 0.008590
# Epoch 83 / 300: Loss = 0.704, Acc = 0.76, LR = 0.008590
# Epoch 84 / 300: Loss = 0.687, Acc = 0.77, LR = 0.006872
# Epoch 85 / 300: Loss = 0.675, Acc = 0.77, LR = 0.006872
# Epoch 86 / 300: Loss = 0.665, Acc = 0.78, LR = 0.006872
# Epoch 87 / 300: Loss = 0.659, Acc = 0.78, LR = 0.006872
# Epoch 88 / 300: Loss = 0.653, Acc = 0.78, LR = 0.006872
# Epoch 89 / 300: Loss = 0.646, Acc = 0.78, LR = 0.006872
# Epoch 90 / 300: Loss = 0.641, Acc = 0.79, LR = 0.006872
# Epoch 91 / 300: Loss = 0.637, Acc = 0.79, LR = 0.005498
# Epoch 92 / 300: Loss = 0.633, Acc = 0.79, LR = 0.005498
# Epoch 93 / 300: Loss = 0.629, Acc = 0.79, LR = 0.005498
# Epoch 94 / 300: Loss = 0.620, Acc = 0.79, LR = 0.005498
# Epoch 95 / 300: Loss = 0.615, Acc = 0.80, LR = 0.005498
# Epoch 96 / 300: Loss = 0.611, Acc = 0.80, LR = 0.005498
# Epoch 97 / 300: Loss = 0.609, Acc = 0.80, LR = 0.005498
# Epoch 98 / 300: Loss = 0.606, Acc = 0.80, LR = 0.004398
# Epoch 99 / 300: Loss = 0.604, Acc = 0.80, LR = 0.004398
# Epoch 100 / 300: Loss = 0.602, Acc = 0.80, LR = 0.004398
# Epoch 101 / 300: Loss = 0.599, Acc = 0.80, LR = 0.004398
# Epoch 102 / 300: Loss = 0.597, Acc = 0.80, LR = 0.004398
# Epoch 103 / 300: Loss = 0.595, Acc = 0.81, LR = 0.004398
# Epoch 104 / 300: Loss = 0.593, Acc = 0.81, LR = 0.004398
# Epoch 105 / 300: Loss = 0.591, Acc = 0.81, LR = 0.003518
# Epoch 106 / 300: Loss = 0.590, Acc = 0.81, LR = 0.003518
# Epoch 107 / 300: Loss = 0.588, Acc = 0.81, LR = 0.003518
# Epoch 108 / 300: Loss = 0.587, Acc = 0.81, LR = 0.003518
# Epoch 109 / 300: Loss = 0.585, Acc = 0.81, LR = 0.003518
# Epoch 110 / 300: Loss = 0.584, Acc = 0.81, LR = 0.003518
# Epoch 111 / 300: Loss = 0.583, Acc = 0.81, LR = 0.003518
# Epoch 112 / 300: Loss = 0.581, Acc = 0.81, LR = 0.002815
# Epoch 113 / 300: Loss = 0.581, Acc = 0.81, LR = 0.002815
# Epoch 114 / 300: Loss = 0.580, Acc = 0.81, LR = 0.002815
# Epoch 115 / 300: Loss = 0.578, Acc = 0.81, LR = 0.002815
# Epoch 116 / 300: Loss = 0.577, Acc = 0.81, LR = 0.002815
# Epoch 117 / 300: Loss = 0.576, Acc = 0.81, LR = 0.002815
# Epoch 118 / 300: Loss = 0.574, Acc = 0.81, LR = 0.002815
# Epoch 119 / 300: Loss = 0.573, Acc = 0.82, LR = 0.002252
# Epoch 120 / 300: Loss = 0.574, Acc = 0.82, LR = 0.002252
# Epoch 121 / 300: Loss = 0.573, Acc = 0.82, LR = 0.002252
# Epoch 122 / 300: Loss = 0.574, Acc = 0.82, LR = 0.002252
# Epoch 123 / 300: Loss = 0.572, Acc = 0.82, LR = 0.002252
# Epoch 124 / 300: Loss = 0.570, Acc = 0.82, LR = 0.002252
# Epoch 125 / 300: Loss = 0.569, Acc = 0.82, LR = 0.002252
# Epoch 126 / 300: Loss = 0.568, Acc = 0.82, LR = 0.001801
# Epoch 127 / 300: Loss = 0.570, Acc = 0.82, LR = 0.001801
# Epoch 128 / 300: Loss = 0.569, Acc = 0.82, LR = 0.001801
# Epoch 129 / 300: Loss = 0.568, Acc = 0.82, LR = 0.001801
# Epoch 130 / 300: Loss = 0.569, Acc = 0.82, LR = 0.001801
# Epoch 131 / 300: Loss = 0.570, Acc = 0.82, LR = 0.001801
# Epoch 132 / 300: Loss = 0.567, Acc = 0.82, LR = 0.001801
# Epoch 133 / 300: Loss = 0.566, Acc = 0.82, LR = 0.001441
# Epoch 134 / 300: Loss = 0.566, Acc = 0.82, LR = 0.001441
# Epoch 135 / 300: Loss = 0.565, Acc = 0.82, LR = 0.001441
# Epoch 136 / 300: Loss = 0.564, Acc = 0.82, LR = 0.001441
# Epoch 137 / 300: Loss = 0.563, Acc = 0.82, LR = 0.001441
# Epoch 138 / 300: Loss = 0.563, Acc = 0.82, LR = 0.001441
# Epoch 139 / 300: Loss = 0.562, Acc = 0.82, LR = 0.001441
# Epoch 140 / 300: Loss = 0.561, Acc = 0.83, LR = 0.001153
# Epoch 141 / 300: Loss = 0.562, Acc = 0.83, LR = 0.001153
# Epoch 142 / 300: Loss = 0.562, Acc = 0.83, LR = 0.001153
# Epoch 143 / 300: Loss = 0.561, Acc = 0.83, LR = 0.001153
# Epoch 144 / 300: Loss = 0.561, Acc = 0.83, LR = 0.001153
# Epoch 145 / 300: Loss = 0.561, Acc = 0.83, LR = 0.001153
# Epoch 146 / 300: Loss = 0.560, Acc = 0.83, LR = 0.001153
# Epoch 147 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000922
# Epoch 148 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000922
# Epoch 149 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000922
# Epoch 150 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000922
# Epoch 151 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000922
# Epoch 152 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000922
# Epoch 153 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000922
# Epoch 154 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000738
# Epoch 155 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000738
# Epoch 156 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000738
# Epoch 157 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000738
# Epoch 158 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000738
# Epoch 159 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000738
# Epoch 160 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000738
# Epoch 161 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000590
# Epoch 162 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000590
# Epoch 163 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000590
# Epoch 164 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000590
# Epoch 165 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000590
# Epoch 166 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000590
# Epoch 167 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000590
# Epoch 168 / 300: Loss = 0.559, Acc = 0.83, LR = 0.000472
# Epoch 169 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000472
# Epoch 170 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000472
# Epoch 171 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000472
# Epoch 172 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000472
# Epoch 173 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000472
# Epoch 174 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000472
# Epoch 175 / 300: Loss = 0.560, Acc = 0.83, LR = 0.000378
# Epoch 176 / 300: Loss = 0.562, Acc = 0.83, LR = 0.000378
# Epoch 177 / 300: Loss = 0.562, Acc = 0.83, LR = 0.000378
# Epoch 178 / 300: Loss = 0.562, Acc = 0.83, LR = 0.000378
# Epoch 179 / 300: Loss = 0.562, Acc = 0.83, LR = 0.000378
# Epoch 180 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000378
# Epoch 181 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000378
# Epoch 182 / 300: Loss = 0.561, Acc = 0.83, LR = 0.000302
# Epoch 183 / 300: Loss = 0.563, Acc = 0.83, LR = 0.000302
# Epoch 184 / 300: Loss = 0.563, Acc = 0.83, LR = 0.000302
# Epoch 185 / 300: Loss = 0.563, Acc = 0.83, LR = 0.000302
# Epoch 186 / 300: Loss = 0.563, Acc = 0.83, LR = 0.000302
# Epoch 187 / 300: Loss = 0.562, Acc = 0.83, LR = 0.000302
# Epoch 188 / 300: Loss = 0.562, Acc = 0.83, LR = 0.000302
# Epoch 189 / 300: Loss = 0.562, Acc = 0.83, LR = 0.000242
# Epoch 190 / 300: Loss = 0.564, Acc = 0.83, LR = 0.000242
# Epoch 191 / 300: Loss = 0.564, Acc = 0.83, LR = 0.000242
# Epoch 192 / 300: Loss = 0.564, Acc = 0.83, LR = 0.000242
# Epoch 193 / 300: Loss = 0.564, Acc = 0.83, LR = 0.000242
# Epoch 194 / 300: Loss = 0.564, Acc = 0.83, LR = 0.000242
# Epoch 195 / 300: Loss = 0.564, Acc = 0.83, LR = 0.000242
# Epoch 196 / 300: Loss = 0.563, Acc = 0.83, LR = 0.000193
# Epoch 197 / 300: Loss = 0.566, Acc = 0.83, LR = 0.000193
# Epoch 198 / 300: Loss = 0.565, Acc = 0.83, LR = 0.000193
# Epoch 199 / 300: Loss = 0.565, Acc = 0.83, LR = 0.000193
# Epoch 200 / 300: Loss = 0.565, Acc = 0.83, LR = 0.000193
# Epoch 201 / 300: Loss = 0.565, Acc = 0.83, LR = 0.000193
# Epoch 202 / 300: Loss = 0.565, Acc = 0.83, LR = 0.000193
# Epoch 203 / 300: Loss = 0.565, Acc = 0.83, LR = 0.000155
# Epoch 204 / 300: Loss = 0.567, Acc = 0.83, LR = 0.000155
# Epoch 205 / 300: Loss = 0.567, Acc = 0.83, LR = 0.000155
# Epoch 206 / 300: Loss = 0.567, Acc = 0.83, LR = 0.000155
# Epoch 207 / 300: Loss = 0.567, Acc = 0.83, LR = 0.000155
# Epoch 208 / 300: Loss = 0.567, Acc = 0.83, LR = 0.000155
# Epoch 209 / 300: Loss = 0.566, Acc = 0.83, LR = 0.000155
# Epoch 210 / 300: Loss = 0.566, Acc = 0.83, LR = 0.000124
# Epoch 211 / 300: Loss = 0.569, Acc = 0.83, LR = 0.000124
# Epoch 212 / 300: Loss = 0.568, Acc = 0.83, LR = 0.000124
# Epoch 213 / 300: Loss = 0.568, Acc = 0.83, LR = 0.000124
# Epoch 214 / 300: Loss = 0.568, Acc = 0.83, LR = 0.000124
# Epoch 215 / 300: Loss = 0.568, Acc = 0.83, LR = 0.000124
# Epoch 216 / 300: Loss = 0.568, Acc = 0.83, LR = 0.000124
# Epoch 217 / 300: Loss = 0.568, Acc = 0.83, LR = 0.000099
# Epoch 218 / 300: Loss = 0.571, Acc = 0.83, LR = 0.000099
# Epoch 219 / 300: Loss = 0.570, Acc = 0.83, LR = 0.000099
# Epoch 220 / 300: Loss = 0.570, Acc = 0.83, LR = 0.000099
# Epoch 221 / 300: Loss = 0.570, Acc = 0.83, LR = 0.000099
# Epoch 222 / 300: Loss = 0.570, Acc = 0.83, LR = 0.000099
# Epoch 223 / 300: Loss = 0.570, Acc = 0.83, LR = 0.000099
# Epoch 224 / 300: Loss = 0.570, Acc = 0.83, LR = 0.000079
# Epoch 225 / 300: Loss = 0.573, Acc = 0.83, LR = 0.000079
# Epoch 226 / 300: Loss = 0.572, Acc = 0.83, LR = 0.000079
# Epoch 227 / 300: Loss = 0.572, Acc = 0.83, LR = 0.000079
# Epoch 228 / 300: Loss = 0.572, Acc = 0.83, LR = 0.000079
# Epoch 229 / 300: Loss = 0.572, Acc = 0.83, LR = 0.000079
# Epoch 230 / 300: Loss = 0.572, Acc = 0.83, LR = 0.000079
# Epoch 231 / 300: Loss = 0.572, Acc = 0.83, LR = 0.000063
# Epoch 232 / 300: Loss = 0.575, Acc = 0.83, LR = 0.000063
# Epoch 233 / 300: Loss = 0.575, Acc = 0.83, LR = 0.000063
# Epoch 234 / 300: Loss = 0.575, Acc = 0.83, LR = 0.000063
# Epoch 235 / 300: Loss = 0.575, Acc = 0.83, LR = 0.000063
# Epoch 236 / 300: Loss = 0.575, Acc = 0.83, LR = 0.000063
# Epoch 237 / 300: Loss = 0.575, Acc = 0.83, LR = 0.000063
# Epoch 238 / 300: Loss = 0.575, Acc = 0.83, LR = 0.000051
# Epoch 239 / 300: Loss = 0.577, Acc = 0.83, LR = 0.000051
# Epoch 240 / 300: Loss = 0.577, Acc = 0.83, LR = 0.000051
# Epoch 241 / 300: Loss = 0.577, Acc = 0.83, LR = 0.000051
# Epoch 242 / 300: Loss = 0.577, Acc = 0.83, LR = 0.000051
# Epoch 243 / 300: Loss = 0.577, Acc = 0.83, LR = 0.000051
# Epoch 244 / 300: Loss = 0.577, Acc = 0.83, LR = 0.000051
# Epoch 245 / 300: Loss = 0.577, Acc = 0.83, LR = 0.000041
# Epoch 246 / 300: Loss = 0.580, Acc = 0.82, LR = 0.000041
# Epoch 247 / 300: Loss = 0.580, Acc = 0.82, LR = 0.000041
# Epoch 248 / 300: Loss = 0.580, Acc = 0.82, LR = 0.000041
# Epoch 249 / 300: Loss = 0.580, Acc = 0.82, LR = 0.000041
# Epoch 250 / 300: Loss = 0.580, Acc = 0.82, LR = 0.000041
# Epoch 251 / 300: Loss = 0.580, Acc = 0.82, LR = 0.000041
# Epoch 252 / 300: Loss = 0.580, Acc = 0.82, LR = 0.000032
# Epoch 253 / 300: Loss = 0.583, Acc = 0.82, LR = 0.000032
# Epoch 254 / 300: Loss = 0.583, Acc = 0.82, LR = 0.000032
# Epoch 255 / 300: Loss = 0.583, Acc = 0.82, LR = 0.000032
# Epoch 256 / 300: Loss = 0.583, Acc = 0.82, LR = 0.000032
# Epoch 257 / 300: Loss = 0.583, Acc = 0.82, LR = 0.000032
# Epoch 258 / 300: Loss = 0.583, Acc = 0.82, LR = 0.000032
# Epoch 259 / 300: Loss = 0.583, Acc = 0.82, LR = 0.000026
# Epoch 260 / 300: Loss = 0.586, Acc = 0.82, LR = 0.000026
# Epoch 261 / 300: Loss = 0.586, Acc = 0.82, LR = 0.000026
# Epoch 262 / 300: Loss = 0.585, Acc = 0.82, LR = 0.000026
# Epoch 263 / 300: Loss = 0.585, Acc = 0.82, LR = 0.000026
# Epoch 264 / 300: Loss = 0.585, Acc = 0.82, LR = 0.000026
# Epoch 265 / 300: Loss = 0.585, Acc = 0.82, LR = 0.000026
# Epoch 266 / 300: Loss = 0.585, Acc = 0.82, LR = 0.000021
# Epoch 267 / 300: Loss = 0.588, Acc = 0.82, LR = 0.000021
# Epoch 268 / 300: Loss = 0.588, Acc = 0.82, LR = 0.000021
# Epoch 269 / 300: Loss = 0.588, Acc = 0.82, LR = 0.000021
# Epoch 270 / 300: Loss = 0.588, Acc = 0.82, LR = 0.000021
# Epoch 271 / 300: Loss = 0.588, Acc = 0.82, LR = 0.000021
# Epoch 272 / 300: Loss = 0.588, Acc = 0.82, LR = 0.000021
# Epoch 273 / 300: Loss = 0.588, Acc = 0.82, LR = 0.000017
# Epoch 274 / 300: Loss = 0.591, Acc = 0.82, LR = 0.000017
# Epoch 275 / 300: Loss = 0.591, Acc = 0.82, LR = 0.000017
# Epoch 276 / 300: Loss = 0.591, Acc = 0.82, LR = 0.000017
# Epoch 277 / 300: Loss = 0.591, Acc = 0.82, LR = 0.000017
# Epoch 278 / 300: Loss = 0.591, Acc = 0.82, LR = 0.000017
# Epoch 279 / 300: Loss = 0.591, Acc = 0.82, LR = 0.000017
# Epoch 280 / 300: Loss = 0.591, Acc = 0.82, LR = 0.000013
# Epoch 281 / 300: Loss = 0.593, Acc = 0.82, LR = 0.000013
# Epoch 282 / 300: Loss = 0.593, Acc = 0.82, LR = 0.000013
# Epoch 283 / 300: Loss = 0.593, Acc = 0.82, LR = 0.000013
# Epoch 284 / 300: Loss = 0.593, Acc = 0.82, LR = 0.000013
# Epoch 285 / 300: Loss = 0.593, Acc = 0.82, LR = 0.000013
# Epoch 286 / 300: Loss = 0.593, Acc = 0.82, LR = 0.000013
# Epoch 287 / 300: Loss = 0.593, Acc = 0.82, LR = 0.000011
# Epoch 288 / 300: Loss = 0.596, Acc = 0.82, LR = 0.000011
# Epoch 289 / 300: Loss = 0.596, Acc = 0.82, LR = 0.000011
# Epoch 290 / 300: Loss = 0.596, Acc = 0.82, LR = 0.000011
# Epoch 291 / 300: Loss = 0.596, Acc = 0.82, LR = 0.000011
# Epoch 292 / 300: Loss = 0.596, Acc = 0.82, LR = 0.000011
# Epoch 293 / 300: Loss = 0.596, Acc = 0.82, LR = 0.000011
# Epoch 294 / 300: Loss = 0.596, Acc = 0.82, LR = 0.000009
# Epoch 295 / 300: Loss = 0.598, Acc = 0.82, LR = 0.000009
# Epoch 296 / 300: Loss = 0.598, Acc = 0.82, LR = 0.000009
# Epoch 297 / 300: Loss = 0.598, Acc = 0.82, LR = 0.000009
# Epoch 298 / 300: Loss = 0.598, Acc = 0.82, LR = 0.000009
# Epoch 299 / 300: Loss = 0.598, Acc = 0.82, LR = 0.000009
# Epoch 300 / 300: Loss = 0.598, Acc = 0.82, LR = 0.000009

# %%
torch.save(model_classical.state_dict(), "lstm_tagger_turkish.pth")

# %%
def print_result(model):
    with torch.no_grad():
        input_sentence = training_data[0][0]
        labels = training_data[0][1]
        inputs = prepare_sequence(input_sentence, word_to_ix)
        tag_scores = model(inputs)

        tag_ids = torch.argmax(tag_scores, dim=1).numpy()
        tag_labels = [ix_to_tag[k] for k in tag_ids]
        print(f"Sentence:  {input_sentence}")
        print(f"Labels:    {labels}")
        print(f"Predicted: {tag_labels}")

# %%
print_result(model_classical)
# Out:
# Sentence:  ['1936', 'yılındayız', 'yılında', 'yız', '.']
# Labels:    ['NUM', '_', 'NOUN', 'AUX', 'PUNCT']
# Predicted: ['PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN']

# %%
df=df.sample(2000)

# %%
training_data = []
word_to_ix = {}
tag_to_ix = {}

for _, row in df.iterrows():
    words = row['Sentence'].split()
    tags = row['UPOS Sequence'].split()
    training_data.append((words, tags))
    for word in words:
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)
    for tag in tags:
        if tag not in tag_to_ix:
            tag_to_ix[tag] = len(tag_to_ix)

print(f"Training Data: {training_data}")
print(f"Word to Index: {word_to_ix}")
print(f"Tag to Index: {tag_to_ix}")
# Out:
# Training Data: [(["Pittsburgh'tan", 'San', "Francisco'ya", 'olan', 'uçuşları', 'listeleyin'], ['PROPN', 'PROPN', 'PROPN', 'ADJ', 'NOUN', 'VERB']), (['Iskarta', 'hisse', 'piyasası', 'ile', 'bağlantılı', 'şirketlerin', 'hisseleri', 'de', 'Cuma', 'günü', 'alt', 'üst', 'oldu', '.'], ['NOUN', 'NOUN', 'NOUN', 'CCONJ', 'ADJ', 'NOUN', 'NOUN', 'CCONJ', 'PROPN', 'NOUN', 'ADJ', 'ADJ', 'VERB', 'PUNCT']), (['Bazen', 'ondan', 'nefret', 'ediyorum', ',', 'dedim', '.'], ['ADV', 'PRON', 'NOUN', 'VERB', 'PUNCT', 'VERB', 'PUNCT']), (['Yok', ',', 'fazlası', 'korkutuyor', '.'], ['ADV', 'PUNCT', 'ADJ', 'VERB', 'PUNCT']), (["Memphis'ten", "Tacoma'ya", 'hangi', 'uçuşların', 'gittiğini', 'söyleyip', 'Los', "Angeles'te", 'duraklama', 'yapabilir', 'misin'], ['PROPN', 'PROPN', 'ADJ', 'NOUN', 'NOUN', 'ADV', 'PROPN', 'PROPN', 'NOUN', 'VERB', 'AUX']), (['O', 'zaman', ',', 'bugünkü', 'hâlinizi', 'rüyada', 'görmemek', 'için', 'uykudan', 'korkmaya', 'başlarsınız', '.'], ['DET', 'NOUN', 'PUNCT', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'PUNCT']), (['PEK', 'GÜLER', 'YÜZLÜ', 'DEĞİLLERDİ', '.'], ['ADV', 'NOUN', 'ADJ', 'AUX', 'PUNCT']), (['Kaptan', ',', 'seyirde', 'olan', 'kazaları', 'tarih', ',', 'saat', 've', 'mevki', 'belirterek', 'bütün', 'ayrıntıları', 'ile', 'yazarak', 'bir', 'rapor', 'haline', 'getirmekle', 'sorumludur', 'sorumlu', 'dur', '.'], ['NOUN', 'PUNCT', 'NOUN', 'AUX', 'NOUN', 'NOUN', 'PUNCT', 'NOUN', 'CCONJ', 'NOUN', 'VERB', 'DET', 'NOUN', 'CCONJ', 'VERB', 'DET', 'NOUN', 'NOUN', 'VERB', '_', 'ADJ', 'AUX', 'PUNCT']), (['TESİSİN', 'GENEL', 'KONSEPTİ', '.'], ['NOUN', 'ADJ', 'NOUN', 'PUNCT']), (['Gaylord', 'Container', ',', 'analistlerin', 'birçok', 'borç', 'taşıdığı', 'için', 'onun', 'hakkında', 'şüpheci', 'olduğunu', 'söyledi', '.'], ['PROPN', 'PROPN', 'PUNCT', 'NOUN', 'DET', 'NOUN', 'ADJ', 'ADP', 'PRON', 'ADV', 'ADJ', 'NOUN', 'VERB', 'PUNCT']), (['Bostan', 'dolabı', 'gacır', 'gucur', 'dönüyordu', '.'], ['NOUN', 'NOUN', 'X', 'X', 'VERB', 'PUNCT']), (['Pazar', 'günü', 'Montreal', "Quebec'den", 'kalkan', 'bir', 'San', 'Diego', 'California', 'uçuşu', 'istiyorum'], ['PROPN', 'NOUN', 'PROPN', 'PROPN', 'ADJ', 'DET', 'PROPN', 'PROPN', 'PROPN', 'NOUN', 'VERB']), (['DENGE', 'YOK', '.'], ['NOUN', 'ADJ', 'PUNCT']), (['Ayırmak', 'için', 'Zerzevat', 'dedim', '.'], ['VERB', 'ADP', 'NOUN', 'VERB', 'PUNCT']), (['Bunlar', 'arasında', 'Jennifer', "Tilly'nin", 'Baker', "Boys'un", 'kadın', 'şarkıcısı', 'seçmeleri', 'de', 'var', '.'], ['PRON', 'NOUN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'NOUN', 'NOUN', 'NOUN', 'CCONJ', 'ADJ', 'PUNCT']), (['Yeni', 'ilişkisinden', 'son', 'derece', 'hoşnut', 've', 'ilk', 'bebeğine', 'veremediği', 'tüm', 'sevgiyi', 'ikincisine', 'vermekte', 'kararlıydı', '.'], ['ADJ', 'NOUN', 'ADJ', 'NOUN', 'ADJ', 'CCONJ', 'ADJ', 'NOUN', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'VERB', 'PUNCT']), (['Otele', 'geldiğimiz', 'zaman', ',', 'kumandanı', 'ölüler', 'gibi', 'sarı', 've', 'soluk', ',', 'bel', 'kayışı', 'takılmış', ',', 'hançeri', 'belinde', ',', 'tören', 'esvabı', 'ile', 'salonu', 'adımlarken', 'bulduk', '.'], ['NOUN', 'ADJ', 'NOUN', 'PUNCT', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'CCONJ', 'ADJ', 'PUNCT', 'NOUN', 'NOUN', 'VERB', 'PUNCT', 'NOUN', 'NOUN', 'PUNCT', 'NOUN', 'NOUN', 'CCONJ', 'NOUN', 'ADV', 'VERB', 'PUNCT']), (['Başka', 'bir', 'deyişle', ',', 'küçük', 'bir', 'volatiliteden', 'zarar', 'gelmez', '.'], ['ADP', 'DET', 'NOUN', 'PUNCT', 'ADJ', 'DET', 'NOUN', 'NOUN', 'VERB', 'PUNCT']), (['Parmağını', 'kapıya', 'kıstırdı', '.'], ['NOUN', 'NOUN', 'VERB', 'PUNCT']), (['Bana', 'Çarşamba', "Cleveland'dan", "Miami'ye", 'olan', 'seyahat', 'için', 'uçuşları', 've', 'ücretleri', 'verin'], ['PRON', 'PROPN', 'PROPN', 'PROPN', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'CCONJ', 'NOUN', 'VERB']), (['yirmi', 'yedinci', 'Ağustos', 'günü', "Boston'dan", 'San', "Francisco'ya", 'ne', 'tür', 'uçaklar', 'uçuyor'], ['NUM', 'ADJ', 'NOUN', 'NOUN', 'PROPN', 'PROPN', 'PROPN', 'ADJ', 'NOUN', 'NOUN', 'VERB']), (['Ahmet', 'aslında', 'çok', 'iyi', 'bir', 'mimar', '.'], ['PROPN', ' ...
# Word to Index: {"Pittsburgh'tan": 0, 'San': 1, "Francisco'ya": 2, 'olan': 3, 'uçuşları': 4, 'listeleyin': 5, 'Iskarta': 6, 'hisse': 7, 'piyasası': 8, 'ile': 9, 'bağlantılı': 10, 'şirketlerin': 11, 'hisseleri': 12, 'de': 13, 'Cuma': 14, 'günü': 15, 'alt': 16, 'üst': 17, 'oldu': 18, '.': 19, 'Bazen': 20, 'ondan': 21, 'nefret': 22, 'ediyorum': 23, ',': 24, 'dedim': 25, 'Yok': 26, 'fazlası': 27, 'korkutuyor': 28, "Memphis'ten": 29, "Tacoma'ya": 30, 'hangi': 31, 'uçuşların': 32, 'gittiğini': 33, 'söyleyip': 34, 'Los': 35, "Angeles'te": 36, 'duraklama': 37, 'yapabilir': 38, 'misin': 39, 'O': 40, 'zaman': 41, 'bugünkü': 42, 'hâlinizi': 43, 'rüyada': 44, 'görmemek': 45, 'için': 46, 'uykudan': 47, 'korkmaya': 48, 'başlarsınız': 49, 'PEK': 50, 'GÜLER': 51, 'YÜZLÜ': 52, 'DEĞİLLERDİ': 53, 'Kaptan': 54, 'seyirde': 55, 'kazaları': 56, 'tarih': 57, 'saat': 58, 've': 59, 'mevki': 60, 'belirterek': 61, 'bütün': 62, 'ayrıntıları': 63, 'yazarak': 64, 'bir': 65, 'rapor': 66, 'haline': 67, 'getirmekle': 68, 'sorumludur': 69, 'sorumlu': 70, 'dur': 71, 'TESİSİN': 72, 'GENEL': 73, 'KONSEPTİ': 74, 'Gaylord': 75, 'Container': 76, 'analistlerin': 77, 'birçok': 78, 'borç': 79, 'taşıdığı': 80, 'onun': 81, 'hakkında': 82, 'şüpheci': 83, 'olduğunu': 84, 'söyledi': 85, 'Bostan': 86, 'dolabı': 87, 'gacır': 88, 'gucur': 89, 'dönüyordu': 90, 'Pazar': 91, 'Montreal': 92, "Quebec'den": 93, 'kalkan': 94, 'Diego': 95, 'California': 96, 'uçuşu': 97, 'istiyorum': 98, 'DENGE': 99, 'YOK': 100, 'Ayırmak': 101, 'Zerzevat': 102, 'Bunlar': 103, 'arasında': 104, 'Jennifer': 105, "Tilly'nin": 106, 'Baker': 107, "Boys'un": 108, 'kadın': 109, 'şarkıcısı': 110, 'seçmeleri': 111, 'var': 112, 'Yeni': 113, 'ilişkisinden': 114, 'son': 115, 'derece': 116, 'hoşnut': 117, 'ilk': 118, 'bebeğine': 119, 'veremediği': 120, 'tüm': 121, 'sevgiyi': 122, 'ikincisine': 123, 'vermekte': 124, 'kararlıydı': 125, 'Otele': 126, 'geldiğimiz': 127, 'kumandanı': 128, 'ölüler': 129, 'gibi': 130, 'sarı': 131, 'soluk': 132, 'bel': 133, 'kayışı': 134, 'takılmış': 135, 'hançeri': 136, 'belinde': 137, 'tören': 138, 'esvabı': 139, 'salonu': 140, 'adımlarken': 141, 'bulduk': 142, 'Başka': 143, 'deyişle': 144, 'küçük': 145, 'volatiliteden': 146, 'zarar': 147, 'gelmez': 148, 'Parmağını': 149, 'kapıya': 150, 'kıstırdı': 151, 'Bana': 152, 'Çarşamba': 153, "Cleveland'dan": 154, "Miami'ye": 155, 'seyahat': 156, 'ücretleri': 157, 'verin': 158, 'yirmi': 159, 'yedinci': 160, 'Ağustos': 161, "Boston'dan": 162, 'ne': 163, 'tür': 164, 'uçaklar': 165, 'uçuyor': 166, 'Ahmet': 167, 'aslında': 168, 'çok': 169, 'iyi': 170, 'mimar': 171, 'Bu': 172, 'doğanın': 173, 'refleksidir': 174, 'refleksi': 175, 'dir': 176, ':': 177, 'Kapanma': 178, '!': 179, 'Boksörleri': 180, 'hatırlayın': 181, 'Baba': 182, 'baba': 183, 'Hoca': 184, 'efendinin': 185, 'gırtlağından': 186, 'yukarısı': 187, 'tam': 188, 'dört': 189, 'tane': 190, 'patlıcan': 191, 'dolması': 192, 'aldı': 193, 'Ama': 194, 'bu': 195, 'orta': 196, 'incelikli': 197, 'teknoloji': 198, 'sadece': 199, 'başlangıç': 200, 'Ben': 201, '-': 202, 'az': 203, 'satıyorum': 204, "Atlanta'ya": 205, 'listesini': 206, 'görmek': 207, 'Yaklaşık': 208, '2': 209, 'yıldır': 210, 'kadar': 211, 'kazanma': 212, 'hırsıyla': 213, 'dolmamıştınız': 214, 'Osmanlı': 215, 'Bankasında': 216, 'çalışan': 217, 'müvekkilesi': 218, 'kış': 219, 'telefon': 220, 'etmiş': 221, 'Ancak': 222, 'yatırım': 223, 'hemen': 224, 'satın': 225, 'alınamaz': 226, 'veya': 227, 'satılmazsa': 228, 'sipariş': 229, 'otomatik': 230, 'olarak': 231, 'iptal': 232, 'edilir': 233, 'Benim': 234, 'mi': 235, "Allah'ım": 236, 'çizgili': 237, 'yüz': 238, '?': 239, '/': 240, 'Ya': 241, 'gözler': 242, 'altındaki': 243, 'mor': 244, 'halkalar': 245, 'şeriat': 246, 'onayı': 247, 'denetimi': 248, 'aranacağı': 249, 'talep': 250, 'olmayabilir': 251, 'ÇOK': 252, 'MEMNUNUZ': 253, 'EKSİKSİZDİ': 254, 'Ve': 255, 'yarından': 256, 'itibaren': 257, 'kılıcım': 258, 'yani': 259, 'kalemim': 260, 'elimde': 261, 'ortaya': 262, 'atılacaktım': 263, 'önce': 264, "Philadel ...
# Tag to Index: {'PROPN': 0, 'ADJ': 1, 'NOUN': 2, 'VERB': 3, 'CCONJ': 4, 'PUNCT': 5, 'ADV': 6, 'PRON': 7, 'AUX': 8, 'DET': 9, 'ADP': 10, '_': 11, 'X': 12, 'NUM': 13, 'INTJ': 14, 'PART': 15, 'SCONJ': 16}

# %%
n_qubits = 4

model_quantum = LSTMTagger(embedding_dim,
                        hidden_dim,
                        vocab_size=len(word_to_ix),
                        tagset_size=len(tag_to_ix),
                        n_qubits=n_qubits,
                        n_qlayers=2)
# Out:
# Tagger will use Quantum LSTM
# weight_shapes = (n_qlayers, n_qubits) = (2, 4)

# %%
history_quantum = train(model_quantum, n_epochs)
# Out:
# Epoch 1 / 300: Loss = 1.914, Acc = 0.41, LR = 0.100000
# Epoch 2 / 300: Loss = 1.678, Acc = 0.46, LR = 0.100000
# Epoch 3 / 300: Loss = 1.606, Acc = 0.47, LR = 0.100000
# Epoch 4 / 300: Loss = 1.669, Acc = 0.46, LR = 0.100000
# Epoch 5 / 300: Loss = 1.624, Acc = 0.46, LR = 0.100000
# Epoch 6 / 300: Loss = 1.612, Acc = 0.48, LR = 0.100000
# Epoch 7 / 300: Loss = 1.697, Acc = 0.45, LR = 0.080000
# Epoch 8 / 300: Loss = 1.651, Acc = 0.47, LR = 0.080000
# Epoch 9 / 300: Loss = 1.637, Acc = 0.47, LR = 0.080000
# Epoch 10 / 300: Loss = 1.686, Acc = 0.45, LR = 0.080000
# Epoch 11 / 300: Loss = 1.932, Acc = 0.37, LR = 0.080000
# Epoch 12 / 300: Loss = 2.014, Acc = 0.34, LR = 0.080000
# Epoch 13 / 300: Loss = 2.010, Acc = 0.34, LR = 0.080000
# Epoch 14 / 300: Loss = 2.053, Acc = 0.33, LR = 0.064000
# Epoch 15 / 300: Loss = 2.045, Acc = 0.33, LR = 0.064000
# Epoch 16 / 300: Loss = 2.038, Acc = 0.33, LR = 0.064000
# Epoch 17 / 300: Loss = 2.035, Acc = 0.33, LR = 0.064000
# Epoch 18 / 300: Loss = 2.042, Acc = 0.32, LR = 0.064000
# Epoch 19 / 300: Loss = 2.037, Acc = 0.33, LR = 0.064000
# Epoch 20 / 300: Loss = 2.027, Acc = 0.32, LR = 0.064000
# Epoch 21 / 300: Loss = 2.031, Acc = 0.32, LR = 0.051200
# Epoch 22 / 300: Loss = 2.016, Acc = 0.33, LR = 0.051200
# Epoch 23 / 300: Loss = 2.035, Acc = 0.32, LR = 0.051200
# Epoch 24 / 300: Loss = 2.037, Acc = 0.32, LR = 0.051200
# Epoch 25 / 300: Loss = 2.020, Acc = 0.33, LR = 0.051200
# Epoch 26 / 300: Loss = 2.025, Acc = 0.32, LR = 0.051200
# Epoch 27 / 300: Loss = 2.012, Acc = 0.33, LR = 0.051200
# Epoch 28 / 300: Loss = 2.035, Acc = 0.32, LR = 0.040960
# Epoch 29 / 300: Loss = 2.012, Acc = 0.33, LR = 0.040960
# Epoch 30 / 300: Loss = 1.992, Acc = 0.34, LR = 0.040960
# Epoch 31 / 300: Loss = 1.991, Acc = 0.34, LR = 0.040960
# Epoch 32 / 300: Loss = 1.970, Acc = 0.34, LR = 0.040960
# Epoch 33 / 300: Loss = 1.969, Acc = 0.35, LR = 0.040960
# Epoch 34 / 300: Loss = 2.000, Acc = 0.34, LR = 0.040960
# Epoch 35 / 300: Loss = 1.976, Acc = 0.34, LR = 0.032768
# Epoch 36 / 300: Loss = 1.945, Acc = 0.35, LR = 0.032768
# Epoch 37 / 300: Loss = 1.941, Acc = 0.35, LR = 0.032768
# Epoch 38 / 300: Loss = 1.991, Acc = 0.34, LR = 0.032768
# Epoch 39 / 300: Loss = 1.962, Acc = 0.34, LR = 0.032768
# Epoch 40 / 300: Loss = 1.977, Acc = 0.34, LR = 0.032768
# Epoch 41 / 300: Loss = 1.965, Acc = 0.34, LR = 0.032768
# Epoch 42 / 300: Loss = 1.940, Acc = 0.36, LR = 0.026214
# Epoch 43 / 300: Loss = 1.927, Acc = 0.36, LR = 0.026214
# Epoch 44 / 300: Loss = 1.998, Acc = 0.33, LR = 0.026214
# Epoch 45 / 300: Loss = 1.993, Acc = 0.33, LR = 0.026214
# Epoch 46 / 300: Loss = 1.995, Acc = 0.33, LR = 0.026214
# Epoch 47 / 300: Loss = 2.010, Acc = 0.33, LR = 0.026214
# Epoch 48 / 300: Loss = 1.998, Acc = 0.33, LR = 0.026214
# Epoch 49 / 300: Loss = 1.993, Acc = 0.33, LR = 0.020972
# Epoch 50 / 300: Loss = 1.960, Acc = 0.35, LR = 0.020972
# Epoch 51 / 300: Loss = 1.926, Acc = 0.36, LR = 0.020972
# Epoch 52 / 300: Loss = 1.921, Acc = 0.36, LR = 0.020972
# Epoch 53 / 300: Loss = 1.928, Acc = 0.36, LR = 0.020972
# Epoch 54 / 300: Loss = 1.919, Acc = 0.36, LR = 0.020972
# Epoch 55 / 300: Loss = 1.949, Acc = 0.35, LR = 0.020972
# Epoch 56 / 300: Loss = 1.919, Acc = 0.37, LR = 0.016777
# Epoch 57 / 300: Loss = 1.845, Acc = 0.40, LR = 0.016777
# Epoch 58 / 300: Loss = 1.902, Acc = 0.38, LR = 0.016777
# Epoch 59 / 300: Loss = 1.916, Acc = 0.37, LR = 0.016777
# Epoch 60 / 300: Loss = 1.909, Acc = 0.37, LR = 0.016777
# Epoch 61 / 300: Loss = 1.881, Acc = 0.38, LR = 0.016777
# Epoch 62 / 300: Loss = 1.851, Acc = 0.39, LR = 0.016777
# Epoch 63 / 300: Loss = 1.869, Acc = 0.39, LR = 0.013422
# Epoch 64 / 300: Loss = 1.841, Acc = 0.39, LR = 0.013422
# Epoch 65 / 300: Loss = 1.803, Acc = 0.40, LR = 0.013422
# Epoch 66 / 300: Loss = 1.801, Acc = 0.40, LR = 0.013422
# Epoch 67 / 300: Loss = 1.830, Acc = 0.39, LR = 0.013422
# Epoch 68 / 300: Loss = 1.846, Acc = 0.39, LR = 0.013422
# Epoch 69 / 300: Loss = 1.858, Acc = 0.38, LR = 0.013422
# Epoch 70 / 300: Loss = 1.884, Acc = 0.37, LR = 0.010737
# Epoch 71 / 300: Loss = 1.828, Acc = 0.38, LR = 0.010737
# Epoch 72 / 300: Loss = 1.811, Acc = 0.39, LR = 0.010737
# Epoch 73 / 300: Loss = 1.859, Acc = 0.38, LR = 0.010737
# Epoch 74 / 300: Loss = 1.876, Acc = 0.37, LR = 0.010737
# Epoch 75 / 300: Loss = 1.872, Acc = 0.38, LR = 0.010737
# Epoch 76 / 300: Loss = 1.862, Acc = 0.38, LR = 0.010737
# Epoch 77 / 300: Loss = 1.902, Acc = 0.37, LR = 0.008590
# Epoch 78 / 300: Loss = 1.838, Acc = 0.39, LR = 0.008590
# Epoch 79 / 300: Loss = 1.820, Acc = 0.39, LR = 0.008590
# Epoch 80 / 300: Loss = 1.823, Acc = 0.39, LR = 0.008590
# Epoch 81 / 300: Loss = 1.834, Acc = 0.39, LR = 0.008590
# Epoch 82 / 300: Loss = 1.873, Acc = 0.38, LR = 0.008590
# Epoch 83 / 300: Loss = 1.841, Acc = 0.38, LR = 0.008590
# Epoch 84 / 300: Loss = 1.872, Acc = 0.38, LR = 0.006872
# Epoch 85 / 300: Loss = 1.832, Acc = 0.39, LR = 0.006872
# Epoch 86 / 300: Loss = 1.823, Acc = 0.39, LR = 0.006872
# Epoch 87 / 300: Loss = 1.816, Acc = 0.39, LR = 0.006872
# Epoch 88 / 300: Loss = 1.848, Acc = 0.39, LR = 0.006872
# Epoch 89 / 300: Loss = 1.846, Acc = 0.38, LR = 0.006872
# Epoch 90 / 300: Loss = 1.846, Acc = 0.38, LR = 0.006872
# Epoch 91 / 300: Loss = 1.842, Acc = 0.38, LR = 0.005498
# Epoch 92 / 300: Loss = 1.813, Acc = 0.40, LR = 0.005498
# Epoch 93 / 300: Loss = 1.788, Acc = 0.40, LR = 0.005498
# Epoch 94 / 300: Loss = 1.822, Acc = 0.38, LR = 0.005498
# Epoch 95 / 300: Loss = 1.789, Acc = 0.40, LR = 0.005498
# Epoch 96 / 300: Loss = 1.808, Acc = 0.39, LR = 0.005498
# Epoch 97 / 300: Loss = 1.817, Acc = 0.39, LR = 0.005498
# Epoch 98 / 300: Loss = 1.791, Acc = 0.41, LR = 0.004398
# Epoch 99 / 300: Loss = 1.711, Acc = 0.43, LR = 0.004398
# Epoch 100 / 300: Loss = 1.766, Acc = 0.41, LR = 0.004398
# Epoch 101 / 300: Loss = 1.774, Acc = 0.41, LR = 0.004398
# Epoch 102 / 300: Loss = 1.787, Acc = 0.40, LR = 0.004398
# Epoch 103 / 300: Loss = 1.780, Acc = 0.40, LR = 0.004398
# Epoch 104 / 300: Loss = 1.798, Acc = 0.40, LR = 0.004398
# Epoch 105 / 300: Loss = 1.782, Acc = 0.40, LR = 0.003518
# Epoch 106 / 300: Loss = 1.758, Acc = 0.41, LR = 0.003518
# Epoch 107 / 300: Loss = 1.732, Acc = 0.41, LR = 0.003518
# Epoch 108 / 300: Loss = 1.754, Acc = 0.41, LR = 0.003518
# Epoch 109 / 300: Loss = 1.772, Acc = 0.40, LR = 0.003518
# Epoch 110 / 300: Loss = 1.737, Acc = 0.42, LR = 0.003518
# Epoch 111 / 300: Loss = 1.764, Acc = 0.41, LR = 0.003518
# Epoch 112 / 300: Loss = 1.755, Acc = 0.41, LR = 0.002815
# Epoch 113 / 300: Loss = 1.704, Acc = 0.43, LR = 0.002815
# Epoch 114 / 300: Loss = 1.670, Acc = 0.44, LR = 0.002815
# Epoch 115 / 300: Loss = 1.664, Acc = 0.44, LR = 0.002815
# Epoch 116 / 300: Loss = 1.652, Acc = 0.45, LR = 0.002815
# Epoch 117 / 300: Loss = 1.623, Acc = 0.46, LR = 0.002815
# Epoch 118 / 300: Loss = 1.658, Acc = 0.45, LR = 0.002815
# Epoch 119 / 300: Loss = 1.674, Acc = 0.42, LR = 0.002252
# Epoch 120 / 300: Loss = 1.615, Acc = 0.45, LR = 0.002252
# Epoch 121 / 300: Loss = 1.543, Acc = 0.47, LR = 0.002252
# Epoch 122 / 300: Loss = 1.526, Acc = 0.49, LR = 0.002252
# Epoch 123 / 300: Loss = 1.523, Acc = 0.50, LR = 0.002252
# Epoch 124 / 300: Loss = 1.545, Acc = 0.47, LR = 0.002252
# Epoch 125 / 300: Loss = 1.578, Acc = 0.47, LR = 0.002252
# Epoch 126 / 300: Loss = 1.542, Acc = 0.48, LR = 0.001801
# Epoch 127 / 300: Loss = 1.405, Acc = 0.52, LR = 0.001801
# Epoch 128 / 300: Loss = 1.359, Acc = 0.55, LR = 0.001801
# Epoch 129 / 300: Loss = 1.432, Acc = 0.52, LR = 0.001801
# Epoch 130 / 300: Loss = 1.460, Acc = 0.50, LR = 0.001801
# Epoch 131 / 300: Loss = 1.488, Acc = 0.49, LR = 0.001801
# Epoch 132 / 300: Loss = 1.501, Acc = 0.48, LR = 0.001801
# Epoch 133 / 300: Loss = 1.377, Acc = 0.52, LR = 0.001441
# Epoch 134 / 300: Loss = 1.274, Acc = 0.56, LR = 0.001441
# Epoch 135 / 300: Loss = 1.150, Acc = 0.60, LR = 0.001441
# Epoch 136 / 300: Loss = 1.077, Acc = 0.62, LR = 0.001441
# Epoch 137 / 300: Loss = 1.142, Acc = 0.59, LR = 0.001441
# Epoch 138 / 300: Loss = 1.437, Acc = 0.51, LR = 0.001441
# Epoch 139 / 300: Loss = 1.353, Acc = 0.51, LR = 0.001441
# Epoch 140 / 300: Loss = 1.557, Acc = 0.48, LR = 0.001153
# Epoch 141 / 300: Loss = 1.236, Acc = 0.58, LR = 0.001153
# Epoch 142 / 300: Loss = 1.212, Acc = 0.59, LR = 0.001153
# Epoch 143 / 300: Loss = 1.234, Acc = 0.57, LR = 0.001153
# Epoch 144 / 300: Loss = 1.099, Acc = 0.62, LR = 0.001153
# Epoch 145 / 300: Loss = 1.062, Acc = 0.63, LR = 0.001153
# Epoch 146 / 300: Loss = 1.119, Acc = 0.60, LR = 0.001153
# Epoch 147 / 300: Loss = 1.091, Acc = 0.61, LR = 0.000922
# Epoch 148 / 300: Loss = 1.015, Acc = 0.65, LR = 0.000922
# Epoch 149 / 300: Loss = 0.991, Acc = 0.66, LR = 0.000922
# Epoch 150 / 300: Loss = 0.973, Acc = 0.66, LR = 0.000922
# Epoch 151 / 300: Loss = 0.954, Acc = 0.66, LR = 0.000922
# Epoch 152 / 300: Loss = 0.943, Acc = 0.67, LR = 0.000922
# Epoch 153 / 300: Loss = 0.989, Acc = 0.65, LR = 0.000922
# Epoch 154 / 300: Loss = 0.939, Acc = 0.67, LR = 0.000738
# Epoch 155 / 300: Loss = 0.919, Acc = 0.68, LR = 0.000738
# Epoch 156 / 300: Loss = 0.906, Acc = 0.68, LR = 0.000738
# Epoch 157 / 300: Loss = 0.899, Acc = 0.68, LR = 0.000738
# Epoch 158 / 300: Loss = 0.892, Acc = 0.69, LR = 0.000738
# Epoch 159 / 300: Loss = 0.884, Acc = 0.69, LR = 0.000738
# Epoch 160 / 300: Loss = 0.878, Acc = 0.69, LR = 0.000738
# Epoch 161 / 300: Loss = 0.870, Acc = 0.69, LR = 0.000590
# Epoch 162 / 300: Loss = 0.863, Acc = 0.69, LR = 0.000590
# Epoch 163 / 300: Loss = 0.855, Acc = 0.70, LR = 0.000590
# Epoch 164 / 300: Loss = 0.849, Acc = 0.70, LR = 0.000590
# Epoch 165 / 300: Loss = 0.844, Acc = 0.70, LR = 0.000590
# Epoch 166 / 300: Loss = 0.840, Acc = 0.70, LR = 0.000590
# Epoch 167 / 300: Loss = 0.836, Acc = 0.70, LR = 0.000590
# Epoch 168 / 300: Loss = 0.831, Acc = 0.70, LR = 0.000472
# Epoch 169 / 300: Loss = 0.827, Acc = 0.70, LR = 0.000472
# Epoch 170 / 300: Loss = 0.823, Acc = 0.70, LR = 0.000472
# Epoch 171 / 300: Loss = 0.819, Acc = 0.70, LR = 0.000472
# Epoch 172 / 300: Loss = 0.816, Acc = 0.71, LR = 0.000472
# Epoch 173 / 300: Loss = 0.813, Acc = 0.71, LR = 0.000472
# Epoch 174 / 300: Loss = 0.809, Acc = 0.71, LR = 0.000472
# Epoch 175 / 300: Loss = 0.807, Acc = 0.71, LR = 0.000378
# Epoch 176 / 300: Loss = 0.802, Acc = 0.71, LR = 0.000378
# Epoch 177 / 300: Loss = 0.800, Acc = 0.71, LR = 0.000378
# Epoch 178 / 300: Loss = 0.797, Acc = 0.71, LR = 0.000378
# Epoch 179 / 300: Loss = 0.795, Acc = 0.71, LR = 0.000378
# Epoch 180 / 300: Loss = 0.793, Acc = 0.71, LR = 0.000378
# Epoch 181 / 300: Loss = 0.790, Acc = 0.71, LR = 0.000378
# Epoch 182 / 300: Loss = 0.788, Acc = 0.71, LR = 0.000302
# Epoch 183 / 300: Loss = 0.786, Acc = 0.71, LR = 0.000302
# Epoch 184 / 300: Loss = 0.783, Acc = 0.72, LR = 0.000302
# Epoch 185 / 300: Loss = 0.781, Acc = 0.72, LR = 0.000302
# Epoch 186 / 300: Loss = 0.779, Acc = 0.72, LR = 0.000302
# Epoch 187 / 300: Loss = 0.778, Acc = 0.72, LR = 0.000302
# Epoch 188 / 300: Loss = 0.776, Acc = 0.72, LR = 0.000302
# Epoch 189 / 300: Loss = 0.774, Acc = 0.72, LR = 0.000242
# Epoch 190 / 300: Loss = 0.772, Acc = 0.72, LR = 0.000242
# Epoch 191 / 300: Loss = 0.771, Acc = 0.72, LR = 0.000242
# Epoch 192 / 300: Loss = 0.769, Acc = 0.72, LR = 0.000242
# Epoch 193 / 300: Loss = 0.768, Acc = 0.72, LR = 0.000242
# Epoch 194 / 300: Loss = 0.767, Acc = 0.72, LR = 0.000242
# Epoch 195 / 300: Loss = 0.766, Acc = 0.72, LR = 0.000242
# Epoch 196 / 300: Loss = 0.764, Acc = 0.72, LR = 0.000193
# Epoch 197 / 300: Loss = 0.763, Acc = 0.72, LR = 0.000193
# Epoch 198 / 300: Loss = 0.762, Acc = 0.72, LR = 0.000193
# Epoch 199 / 300: Loss = 0.761, Acc = 0.72, LR = 0.000193
# Epoch 200 / 300: Loss = 0.760, Acc = 0.72, LR = 0.000193
# Epoch 201 / 300: Loss = 0.759, Acc = 0.72, LR = 0.000193
# Epoch 202 / 300: Loss = 0.758, Acc = 0.72, LR = 0.000193
# Epoch 203 / 300: Loss = 0.757, Acc = 0.72, LR = 0.000155
# Epoch 204 / 300: Loss = 0.756, Acc = 0.72, LR = 0.000155
# Epoch 205 / 300: Loss = 0.755, Acc = 0.72, LR = 0.000155
# Epoch 206 / 300: Loss = 0.753, Acc = 0.72, LR = 0.000155
# Epoch 207 / 300: Loss = 0.752, Acc = 0.72, LR = 0.000155
# Epoch 208 / 300: Loss = 0.751, Acc = 0.72, LR = 0.000155
# Epoch 209 / 300: Loss = 0.751, Acc = 0.72, LR = 0.000155
# Epoch 210 / 300: Loss = 0.750, Acc = 0.72, LR = 0.000124
# Epoch 211 / 300: Loss = 0.749, Acc = 0.72, LR = 0.000124
# Epoch 212 / 300: Loss = 0.748, Acc = 0.72, LR = 0.000124
# Epoch 213 / 300: Loss = 0.748, Acc = 0.72, LR = 0.000124
# Epoch 214 / 300: Loss = 0.747, Acc = 0.72, LR = 0.000124
# Epoch 215 / 300: Loss = 0.746, Acc = 0.72, LR = 0.000124
# Epoch 216 / 300: Loss = 0.746, Acc = 0.72, LR = 0.000124
# Epoch 217 / 300: Loss = 0.745, Acc = 0.72, LR = 0.000099
# Epoch 218 / 300: Loss = 0.744, Acc = 0.72, LR = 0.000099
# Epoch 219 / 300: Loss = 0.744, Acc = 0.72, LR = 0.000099
# Epoch 220 / 300: Loss = 0.743, Acc = 0.72, LR = 0.000099
# Epoch 221 / 300: Loss = 0.743, Acc = 0.72, LR = 0.000099
# Epoch 222 / 300: Loss = 0.743, Acc = 0.72, LR = 0.000099
# Epoch 223 / 300: Loss = 0.742, Acc = 0.72, LR = 0.000099
# Epoch 224 / 300: Loss = 0.742, Acc = 0.72, LR = 0.000079
# Epoch 225 / 300: Loss = 0.741, Acc = 0.72, LR = 0.000079
# Epoch 226 / 300: Loss = 0.741, Acc = 0.72, LR = 0.000079
# Epoch 227 / 300: Loss = 0.740, Acc = 0.72, LR = 0.000079
# Epoch 228 / 300: Loss = 0.740, Acc = 0.72, LR = 0.000079
# Epoch 229 / 300: Loss = 0.740, Acc = 0.73, LR = 0.000079
# Epoch 230 / 300: Loss = 0.739, Acc = 0.73, LR = 0.000079
# Epoch 231 / 300: Loss = 0.739, Acc = 0.73, LR = 0.000063
# Epoch 232 / 300: Loss = 0.738, Acc = 0.73, LR = 0.000063
# Epoch 233 / 300: Loss = 0.738, Acc = 0.73, LR = 0.000063
# Epoch 234 / 300: Loss = 0.738, Acc = 0.73, LR = 0.000063
# Epoch 235 / 300: Loss = 0.737, Acc = 0.73, LR = 0.000063
# Epoch 236 / 300: Loss = 0.737, Acc = 0.73, LR = 0.000063
# Epoch 237 / 300: Loss = 0.737, Acc = 0.73, LR = 0.000063
# Epoch 238 / 300: Loss = 0.737, Acc = 0.73, LR = 0.000051
# Epoch 239 / 300: Loss = 0.736, Acc = 0.73, LR = 0.000051
# Epoch 240 / 300: Loss = 0.736, Acc = 0.73, LR = 0.000051
# Epoch 241 / 300: Loss = 0.736, Acc = 0.73, LR = 0.000051
# Epoch 242 / 300: Loss = 0.735, Acc = 0.73, LR = 0.000051
# Epoch 243 / 300: Loss = 0.735, Acc = 0.73, LR = 0.000051
# Epoch 244 / 300: Loss = 0.735, Acc = 0.73, LR = 0.000051
# Epoch 245 / 300: Loss = 0.735, Acc = 0.73, LR = 0.000041
# Epoch 246 / 300: Loss = 0.734, Acc = 0.73, LR = 0.000041
# Epoch 247 / 300: Loss = 0.734, Acc = 0.73, LR = 0.000041
# Epoch 248 / 300: Loss = 0.734, Acc = 0.73, LR = 0.000041
# Epoch 249 / 300: Loss = 0.734, Acc = 0.73, LR = 0.000041
# Epoch 250 / 300: Loss = 0.734, Acc = 0.73, LR = 0.000041
# Epoch 251 / 300: Loss = 0.734, Acc = 0.73, LR = 0.000041
# Epoch 252 / 300: Loss = 0.733, Acc = 0.73, LR = 0.000032
# Epoch 253 / 300: Loss = 0.733, Acc = 0.73, LR = 0.000032
# Epoch 254 / 300: Loss = 0.733, Acc = 0.73, LR = 0.000032
# Epoch 255 / 300: Loss = 0.733, Acc = 0.73, LR = 0.000032
# Epoch 256 / 300: Loss = 0.733, Acc = 0.73, LR = 0.000032
# Epoch 257 / 300: Loss = 0.732, Acc = 0.73, LR = 0.000032
# Epoch 258 / 300: Loss = 0.732, Acc = 0.73, LR = 0.000032
# Epoch 259 / 300: Loss = 0.732, Acc = 0.73, LR = 0.000026
# Epoch 260 / 300: Loss = 0.732, Acc = 0.73, LR = 0.000026
# Epoch 261 / 300: Loss = 0.732, Acc = 0.73, LR = 0.000026
# Epoch 262 / 300: Loss = 0.732, Acc = 0.73, LR = 0.000026
# Epoch 263 / 300: Loss = 0.732, Acc = 0.73, LR = 0.000026
# Epoch 264 / 300: Loss = 0.732, Acc = 0.73, LR = 0.000026
# Epoch 265 / 300: Loss = 0.731, Acc = 0.73, LR = 0.000026
# Epoch 266 / 300: Loss = 0.731, Acc = 0.73, LR = 0.000021
# Epoch 267 / 300: Loss = 0.731, Acc = 0.73, LR = 0.000021
# Epoch 268 / 300: Loss = 0.731, Acc = 0.73, LR = 0.000021
# Epoch 269 / 300: Loss = 0.731, Acc = 0.73, LR = 0.000021
# Epoch 270 / 300: Loss = 0.731, Acc = 0.73, LR = 0.000021
# Epoch 271 / 300: Loss = 0.731, Acc = 0.73, LR = 0.000021
# Epoch 272 / 300: Loss = 0.731, Acc = 0.73, LR = 0.000021
# Epoch 273 / 300: Loss = 0.731, Acc = 0.73, LR = 0.000017
# Epoch 274 / 300: Loss = 0.730, Acc = 0.73, LR = 0.000017
# Epoch 275 / 300: Loss = 0.730, Acc = 0.73, LR = 0.000017
# Epoch 276 / 300: Loss = 0.730, Acc = 0.73, LR = 0.000017
# Epoch 277 / 300: Loss = 0.730, Acc = 0.73, LR = 0.000017
# Epoch 278 / 300: Loss = 0.730, Acc = 0.73, LR = 0.000017
# Epoch 279 / 300: Loss = 0.730, Acc = 0.73, LR = 0.000017
# Epoch 280 / 300: Loss = 0.730, Acc = 0.73, LR = 0.000013
# Epoch 281 / 300: Loss = 0.730, Acc = 0.73, LR = 0.000013
# Epoch 282 / 300: Loss = 0.730, Acc = 0.73, LR = 0.000013
# Epoch 283 / 300: Loss = 0.730, Acc = 0.73, LR = 0.000013
# Epoch 284 / 300: Loss = 0.730, Acc = 0.73, LR = 0.000013
# Epoch 285 / 300: Loss = 0.730, Acc = 0.73, LR = 0.000013
# Epoch 286 / 300: Loss = 0.730, Acc = 0.73, LR = 0.000013
# Epoch 287 / 300: Loss = 0.730, Acc = 0.73, LR = 0.000011
# Epoch 288 / 300: Loss = 0.729, Acc = 0.73, LR = 0.000011
# Epoch 289 / 300: Loss = 0.729, Acc = 0.73, LR = 0.000011
# Epoch 290 / 300: Loss = 0.729, Acc = 0.73, LR = 0.000011
# Epoch 291 / 300: Loss = 0.729, Acc = 0.73, LR = 0.000011
# Epoch 292 / 300: Loss = 0.729, Acc = 0.73, LR = 0.000011
# Epoch 293 / 300: Loss = 0.729, Acc = 0.73, LR = 0.000011
# Epoch 294 / 300: Loss = 0.729, Acc = 0.73, LR = 0.000009
# Epoch 295 / 300: Loss = 0.729, Acc = 0.73, LR = 0.000009
# Epoch 296 / 300: Loss = 0.729, Acc = 0.73, LR = 0.000009
# Epoch 297 / 300: Loss = 0.729, Acc = 0.73, LR = 0.000009
# Epoch 298 / 300: Loss = 0.729, Acc = 0.73, LR = 0.000009
# Epoch 299 / 300: Loss = 0.729, Acc = 0.73, LR = 0.000009
# Epoch 300 / 300: Loss = 0.729, Acc = 0.73, LR = 0.000009

# %%
torch.save(model_quantum.state_dict(), "qlstm_tagger_turkish.pth")

# %%
print_result(model_quantum)
# Out:
# Sentence:  ["Pittsburgh'tan", 'San', "Francisco'ya", 'olan', 'uçuşları', 'listeleyin']
# Labels:    ['PROPN', 'PROPN', 'PROPN', 'ADJ', 'NOUN', 'VERB']
# Predicted: ['ADV', 'ADV', 'ADV', 'ADJ', 'ADP', 'ADV']
